# %% [markdown]
# ## nfl lines machine learning project
#
#
# source data for historical spreads and game scores
# http://www.repole.com/sun4cast/data.html

# %%
import os

# define source and data directories
homeDir = "".join([os.environ['HOME'], os.path.sep])


#codeDir = "".join([homeDir, 'gitdev/bitbucket.org/littlea1/mlkaggle/nfl', os.path.sep])
codeDir = "".join([homeDir, 'repos/mlnfl/nfl', os.path.sep])
dataRoot = "".join([codeDir, "data", os.path.sep])
os.chdir(codeDir)

print(codeDir)
dataRoot
# Out:
# /Users/amit.bhattacharyya/repos/mlnfl/nfl/
# '/Users/amit.bhattacharyya/repos/mlnfl/nfl/data/'

# %%
# %matplotlib inline

from __future__ import division
from __future__ import print_function
import os
import numpy as np
import pandas as pd
import madden
import sklearn_pandas
import matplotlib.pyplot as plt

# %%
# lookup files
from referencedata import ReferenceData
lookupFiles = { 'teams' : {'file': 'nflTeams.csv' },
                'seasons' : {'file': 'seasons.csv' },
               }

lookupDir = "".join([dataRoot, 'lookup', os.path.sep])

print ("lookupFiles = %s" % lookupFiles)
print ("lookupDir = %s" % lookupDir)
# Out:
# lookupFiles = {'seasons': {'file': 'seasons.csv'}, 'teams': {'file': 'nflTeams.csv'}}
# lookupDir = /Users/amit.bhattacharyya/repos/mlnfl/nfl/data/lookup/

# %%
# in notebook, leave all the diagnostic outputs since this is not the real thing
# we are using the nb to investigate
olookups = ReferenceData(lookupDir)
olookups.teams_df
# Out:
#                       city  mascot league division  year
# team
# Baltimore Ravens       NaN     NaN    afc    north   NaN
# New England Patriots   NaN     NaN    afc     east   NaN
# Tennessee Titans       NaN     NaN    afc    south   NaN
# Atlanta Falcons        NaN     NaN    nfc    south   NaN
# Tampa Bay Buccaneers   NaN     NaN    nfc    south   NaN
# Kansas City Chiefs     NaN     NaN    afc     west   NaN
# Cincinnati Bengals     NaN     NaN    afc    north   NaN
# Miami Dolphins         NaN     NaN    afc     east   NaN
# Seattle Seahawks       NaN     NaN    nfc     west   NaN
# Minnesota Vikings      NaN     NaN    nfc    north   NaN
# Oakland Raiders        NaN     NaN    afc     west   NaN
# Arizona Cardinals      NaN     NaN    nfc     west   NaN
# Green Bay Packers      NaN     NaN    nfc    north   NaN
# New York Giants        NaN     NaN    nfc     east   NaN
# Philadelphia Eagles    NaN     NaN    nfc     east   NaN
# Houston Texans         NaN     NaN    afc    south   NaN
# New York Jets          NaN     NaN    afc     east   NaN
# San Diego Chargers     NaN     NaN    afc     west   NaN
# Cleveland Browns       NaN     NaN    afc    north   NaN
# Carolina Panthers      NaN     NaN    nfc    south   NaN
# St Louis Rams          NaN     NaN    nfc     west   NaN
# Washington Redskins    NaN     NaN    nfc     east   NaN
# Dallas Cowboys         NaN     NaN    nfc     east   NaN
# New Orleans Saints     NaN     NaN    nfc    south   NaN
# Detroit Lions          NaN     NaN    nfc    north   NaN
# Jacksonville Jaguars   NaN     NaN    afc    south   NaN
# Denver Broncos         NaN     NaN    afc     west   NaN
# San Francisco 49ers    NaN     NaN    nfc     west   NaN
# Pittsburgh Steelers    NaN     NaN    afc    north   NaN
# Indianapolis Colts     NaN     NaN    afc    south   NaN
# Buffalo Bills          NaN     NaN    afc     east   NaN
# Chicago Bears          NaN     NaN    nfc    north   NaN
#
# [32 rows x 5 columns]

# %%
al_seasons = olookups.seasons_df
al_seasons.tail()
# Out:
#             start  winner
# season
# 2010    13-Sep-10    1590
# 2011    12-Sep-11    1670
# 2012    10-Sep-12    1632
# 2013     9-Sep-13    1653
# 2014     8-Sep-14     NaN
#
# [5 rows x 2 columns]

# %%
al_teams = olookups.teams_df
al_teams.head()
# Out:
#                       city  mascot league division  year
# team
# Baltimore Ravens       NaN     NaN    afc    north   NaN
# New England Patriots   NaN     NaN    afc     east   NaN
# Tennessee Titans       NaN     NaN    afc    south   NaN
# Atlanta Falcons        NaN     NaN    nfc    south   NaN
# Tampa Bay Buccaneers   NaN     NaN    nfc    south   NaN
#
# [5 rows x 5 columns]

# %%
team1 = al_teams.loc["Tennessee Titans", ["league", "division"]].reindex()
team2 = al_teams.loc["Indianapolis Colts", ["league", "division"]].reindex()
print(team1)
print(team2)
# Out:
# league        afc
# division    south
# Name: Tennessee Titans, dtype: object
# league        afc
# division    south
# Name: Indianapolis Colts, dtype: object

# %%
type(olookups.seasons_df.loc[int("2012"), "start"])
# Out:
# str

# %%
#team1["league"] == team2["league"] & team1["division"] == team2["division"]
team1 = al_teams.loc["Tennessee Titans", ]
team2 = al_teams.loc["Indianapolis Colts", ]
team1["league"] == team2["league"]
# Out:
# True

# %%
### NEW multi-season training
import madden
reload(madden)

# need to be arrays
trainYears = [2013] #range(2008,2013) 
#trainYears = range(2011,2014) 
testYear = [2014]

# training data set - includes one extra year for prev yr record
seasons = np.array(trainYears)
print ("training seasons >> ", seasons)
# Out:
# training seasons >>  [2013]

# %%
reload(madden)
# read all the 
dfAllGames = madden.readGamesAll(madden.PATH_TO_NFL_LINES, seasons)

# %%
#dfAllTeams[dfAllTeams.team == "Dallas Cowboys"]
#for i, game in dfAllGames.iterrows():
#    print(game.season)
#    print(olookups.getSeasonStartDate(game.season))

# %%
# read all the game
dfAllGames = madden.readGamesAll(madden.PATH_TO_NFL_LINES, seasons)

# compile season record for all teams
dfAllTeams = madden.seasonRecord(dfAllGames, olookups)

# apply season records and compute other fields for all games
dfAllGames = madden.processGames(dfAllGames, dfAllTeams, olookups)
# remove extra year of data 
dfAllGames = dfAllGames[dfAllGames.season.isin(seasons)]

# define independent variables for logistic regression
features = ['favoredRecord','underdogRecord',  # current year records of both teams
            'prevFavoredRecord','prevUnderdogRecord', # prev year records, helps early in season when only few games played
            'gameWeek',  # week in season, should make a good/bad record later in season more important
            'absLine',  # absolute value of spread since favored team already determined
            'divisionGame', # T/F, usually more competitive rivalry games, i.e. bad teams still win home division games.
            'favoredHomeGame', # T/F, important since output of classifier is "did the favored team win?"
            ]
# run the logistic regression
logreg = madden.runML(dfAllGames,features)

# use different test set 
seasonTest = np.array(testYear) # should be only one year
print ("results for >> ", seasonTest)
dfGamesTest = madden.readGamesAll(madden.PATH_TO_NFL_LINES, seasonTest)
dfTeamsTest = madden.seasonRecord(dfGamesTest,olookups)
dfGamesTest = madden.processGames(dfGamesTest, dfTeamsTest, olookups)
dfGamesTest = dfGamesTest[dfGamesTest.season.isin(seasonTest)]

# apply results of logistic regression to the test set
dfPredict = madden.predictGames(dfGamesTest,logreg,features)

# apply ranking logic and determine scoring outcomes for league
dfAll = madden.rankGames(dfPredict,olookups,seasonTest[0])
# Out:
# training data accuracy =  0.70703125
# results for >>  [2014]

# %%
# predict one week of current season
iweek = 1
reload(madden)

# use different test set 
testYear = [2014]
seasonTest = np.array(testYear) # should be only one year
print ("results for >> ", seasonTest)

dfGamesTest = madden.readGamesAll(madden.PATH_TO_NFL_LINES, seasonTest)
dfTeamsTest = madden.seasonRecord(dfGamesTest,olookups)
dfGamesTest = madden.processGames(dfGamesTest, dfTeamsTest, olookups)
dfGamesTest = dfGamesTest[dfGamesTest.season.isin(seasonTest)]

# pick only this weeks games for predict
dfTest = dfGamesTest[dfGamesTest.gameWeek == iweek]

# apply results of logistic regression to the test set
dfPredict = madden.predictGames(dfTest,logreg,features)
# apply ranking logic and determine scoring outcomes for league
dfAll = madden.rankGames(dfPredict,olookups,seasonTest[0])
# Out:
# results for >>  [2014]

# %%
dfAll.columns
# Out:
# Index([u'Date', u'Visitor', u'Visitor Score', u'Home Team', u'Home Score', u'Line', u'Total Line', u'season', u'favorite', u'underdog', u'favoredHomeGame', u'divisionGame', u'homeWin', u'favoredWin', u'gameWeek', u'homeRecord', u'visitorRecord', u'favoredRecord', u'underdogRecord', u'prevFavoredRecord', u'prevUnderdogRecord', u'absLine', u'predict_proba', u'predict_proba_abs', u'decision_fxn', u'predictWin', u'lineGuess', u'probaGuess', u'probaAbsGuess', u'lineScore', u'probaScore1', u'probaScore2', u'probaScore3'], dtype='object')

# %%
# display weekly ranking output

# ranking methods choices
# 0. pick based on spread
# 1. always pick favored team, rank by probability of win
# 2. pick winner based on abs(probability - .5), rank by probability
# 3. pick winner based on abs(probability - .5), rank by abs(probability - .5)

rankMethod = 2

dispCols = ['season','gameWeek','Visitor','visitorRecord','Home Team','homeRecord',
            'Line','prevFavoredRecord','prevUnderdogRecord','predict_proba',
            'lineGuess','probaGuess', 'probaAbsGuess', 'predictTeam']


dfAll['predictTeam'] = np.where((dfAll['predict_proba'] - .5) > 0 , dfAll['favorite'], dfAll['underdog'])
guessCol = 'probaGuess'
predictCols = ['predictTeam', guessCol, 'favorite','lineGuess', 'Line']
dfAll[predictCols].sort(guessCol)
# Out:
#                predictTeam  probaGuess              favorite  lineGuess  Line
# 8431       Atlanta Falcons           1    New Orleans Saints          5    -3
# 8438   Washington Redskins           2        Houston Texans          3     2
# 8442   San Francisco 49ers           3   San Francisco 49ers          8    -5
# 8440  New England Patriots           4  New England Patriots         10    -5
# 8432         St Louis Rams           5         St Louis Rams          7     4
# 8435         New York Jets           6         New York Jets         11     5
# 8444         Detroit Lions           7         Detroit Lions          6     4
# 8445     Arizona Cardinals           8     Arizona Cardinals          4     3
# 8439    Kansas City Chiefs           9    Kansas City Chiefs          9     5
# 8436      Baltimore Ravens          10      Baltimore Ravens          1     1
# 8441  Tampa Bay Buccaneers          11  Tampa Bay Buccaneers          2     1
# 8430      Seattle Seahawks          12      Seattle Seahawks         12     5
# 8437         Chicago Bears          13         Chicago Bears         14     7
# 8433   Pittsburgh Steelers          14   Pittsburgh Steelers         13     6
# 8434   Philadelphia Eagles          15   Philadelphia Eagles         16    10
# 8443        Denver Broncos          16        Denver Broncos         15     7
#
# [16 rows x 5 columns]

# %%
# diagnostics ... weekly outcomes
g = dfAll.groupby('gameWeek')['lineScore','probaScore1','probaScore2','probaScore3'].sum()
print(g)
g.sum()
# Out:
#           lineScore  probaScore1  probaScore2  probaScore3
# gameWeek
# 1               NaN          NaN            0            0
#
# [1 rows x 4 columns]
# lineScore     NaN
# probaScore1   NaN
# probaScore2     0
# probaScore3     0
# dtype: float64

# %%
# display details for a single week
dispWeek = 1
dispCols = ['season','gameWeek','Visitor','Home Team',
            'prevFavoredRecord','Line','predict_proba','Visitor Score',
            'Home Score','favoredWin','predictWin','lineGuess','probaGuess', 'lineScore','probaScore1','probaScore2']

print(dfAll[dfAll.gameWeek == dispWeek]['lineScore'].sum())
dfAll[dfAll.gameWeek == dispWeek][dispCols]
# Out:
# nan
#       season  gameWeek               Visitor             Home Team  \
# 8436    2014         1    Cincinnati Bengals      Baltimore Ravens
# 8441    2014         1     Carolina Panthers  Tampa Bay Buccaneers
# 8438    2014         1   Washington Redskins        Houston Texans
# 8445    2014         1    San Diego Chargers     Arizona Cardinals
# 8431    2014         1    New Orleans Saints       Atlanta Falcons
# 8444    2014         1       New York Giants         Detroit Lions
# 8432    2014         1     Minnesota Vikings         St Louis Rams
# 8442    2014         1   San Francisco 49ers        Dallas Cowboys
# 8439    2014         1      Tennessee Titans    Kansas City Chiefs
# 8440    2014         1  New England Patriots        Miami Dolphins
# 8435    2014         1       Oakland Raiders         New York Jets
# 8430    2014         1     Green Bay Packers      Seattle Seahawks
# 8433    2014         1      Cleveland Browns   Pittsburgh Steelers
# 8437    2014         1         Buffalo Bills         Chicago Bears
# 8443    2014         1    Indianapolis Colts        Denver Broncos
# 8434    2014         1  Jacksonville Jaguars   Philadelphia Eagles
#
#       prevFavoredRecord  Line  predict_proba  Visitor Score  Home Score  \
# 8436             0.5000     1       0.630969            NaN         NaN
# 8441             0.2500     1       0.637192            NaN         NaN
# 8438             0.1250     2       0.498908            NaN         NaN
# 8445             0.6250     3       0.600857            NaN         NaN
# 8431             0.6875    -3       0.468757            NaN         NaN
# 8444             0.4375     4       0.599942            NaN         NaN
# 8432             0.4375     4       0.577832            NaN         NaN
# 8442             0.7500    -5       0.504209            NaN         NaN
# 8439             0.6875     5       0.628490            NaN         NaN
# 8440             0.7500    -5       0.566013            NaN         NaN
# 8435             0.5000     5       0.592567            NaN         NaN
# 8430             0.8125     5       0.641261            NaN         NaN
# 8433             0.5000     6       0.673712            NaN         NaN
# 8437             0.5000     7       0.661339            NaN         NaN
# 8443             0.8125     7       0.715285            NaN         NaN
# 8434             0.6250    10       0.709377            NaN         NaN
#
#       favoredWin  predictWin  lineGuess  probaGuess  lineScore  probaScore1  \
# 8436         NaN           0          1          10        NaN          NaN
# 8441         NaN           0          2          11        NaN          NaN
# 8438         NaN           0          3           2        NaN          NaN
# 8445         NaN           0          4           8        NaN          NaN
# 8431         NaN           0          5           1        NaN          NaN
# 8444         NaN           0          6           7        NaN          NaN
# 8432         NaN           0          7           5        NaN          NaN
# 8442         NaN           0          8           3        NaN          NaN
# 8439         NaN           0          9           9        NaN          NaN
# 8440         NaN           0         10           4        NaN          NaN
# 8435         NaN           0         11           6        NaN          NaN
# 8430         NaN           0         12          12        NaN          NaN
# 8433         NaN           0         13          14        NaN          NaN
# 8437         NaN           0         14          13        NaN          NaN
# 8443         NaN           0         15          16        NaN          NaN
# 8434         NaN           0         16          15        NaN          NaN
#
#       probaScore2
# 8436            0
# 8441            0
# 8438            0
# 8445            0
# 8431            0
# 8444            0
# 8432            0
# 8442            0
# 8439            0
# 8440            0
# 8435            0
# 8430            0
# 8433            0
# 8437            0
# 8443            0
# 8434            0
#
# [16 rows x 16 columns]

# %%
# diagnostics ... display all columns
dfAllGames.columns
# Out:
# Index([u'Date', u'Visitor', u'Visitor Score', u'Home Team', u'Home Score', u'Line', u'Total Line', u'season', u'favoredHomeGame', u'divisionGame', u'homeWin', u'favoredWin', u'gameWeek', u'homeRecord', u'visitorRecord', u'favoredRecord', u'underdogRecord', u'prevFavoredRecord', u'prevUnderdogRecord', u'absLine'], dtype='object')

# %%
# diagnostics ... plot outcomes of games
nWin = dfAllGames.favoredWin.index.tolist()
nLose = dfAllGames[dfAllGames['favoredWin'] == 0].index.tolist()

plt.plot(dfAllGames.favoredRecord[nWin],dfAllGames.underdogRecord[nWin],'bx')
plt.plot(dfAllGames.favoredRecord[nLose],dfAllGames.underdogRecord[nLose],'rx')

# %%
# diagnostics ... logreg variables

# print classifiers
print("classifiers > ",logreg.classes_)

# coefficients
cc = logreg.coef_
cc.shape
print("coeffs")
for ii,ff in enumerate(features):
    print(ii,ff,cc[0][ii])
# Out:
# classifiers >  [0 1]
# coeffs
# 0 favoredRecord 1.91252475964
# 1 underdogRecord -1.54131295184
# 2 prevFavoredRecord 0.0754170412348
# 3 prevUnderdogRecord 0.730741963582
# 4 gameWeek -0.0126558814763
# 5 absLine 0.101668474925
# 6 divisionGame 0.248762869133
# 7 favoredHomeGame 0.559291599483

# %%
range(2013,2014)

# %%
[ ff for ff in features]

# %%
cc = logreg.coef_

# %%
logreg.get_params

# %%
int(olookups.seasons_df.loc[int(2013), "winner"])

# %%
len(dfAllGames)/16
# Out:
# 16.0

# %%
dfAllGames[dfAllGames.gameWeek < 2]
# Out:
#             Date               Visitor  Visitor Score             Home Team  \
# 8174  09/05/2013      Baltimore Ravens             27        Denver Broncos
# 8175  09/08/2013  New England Patriots             23         Buffalo Bills
# 8176  09/08/2013      Tennessee Titans             16   Pittsburgh Steelers
# 8177  09/08/2013       Atlanta Falcons             17    New Orleans Saints
# 8178  09/08/2013  Tampa Bay Buccaneers             17         New York Jets
# 8179  09/08/2013    Kansas City Chiefs             28  Jacksonville Jaguars
# 8180  09/08/2013    Cincinnati Bengals             21         Chicago Bears
# 8181  09/08/2013        Miami Dolphins             23      Cleveland Browns
# 8182  09/08/2013      Seattle Seahawks             12     Carolina Panthers
# 8183  09/08/2013     Minnesota Vikings             24         Detroit Lions
# 8184  09/08/2013       Oakland Raiders             17    Indianapolis Colts
# 8185  09/08/2013     Arizona Cardinals             24         St Louis Rams
# 8186  09/08/2013     Green Bay Packers             28   San Francisco 49ers
# 8187  09/08/2013       New York Giants             31        Dallas Cowboys
# 8188  09/09/2013   Philadelphia Eagles             33   Washington Redskins
# 8189  09/09/2013        Houston Texans             31    San Diego Chargers
#
#       Home Score  Line Total Line  season  favoredHomeGame  divisionGame  \
# 8174          49   7.5       49.5    2013                1             0
# 8175          21 -10.5       51.5    2013                0             1
# 8176           9   6.0       42.0    2013                1             0
# 8177          23   3.5       56.0    2013                1             1
# 8178          18  -6.0       39.0    2013                0             0
# 8179           2  -4.5       43.0    2013                0             0
# 8180          24   3.0       42.0    2013                1             0
# 8181          10   2.5       40.5    2013                1             0
# 8182           7  -3.5       45.0    2013                0             0
# 8183          34   4.5       47.5    2013                1             1
# 8184          21  11.5       45.5    2013                1             0
# 8185          27   3.5       41.5    2013                1             1
# 8186          34   5.0       48.5    2013                1             0
# 8187          36   3.5       50.0    2013                1             1
# 8188          27   4.5       53.5    2013                1             1
# 8189          28  -6.5       45.5    2013                0             0
#
#       homeWin  favoredWin  gameWeek  homeRecord  visitorRecord  favoredRecord  \
# 8174        1           1         1           0              0              0
# 8175        0           1         1           0              0              0
# 8176        0           0         1           0              0              0
# 8177        1           1         1           0              0              0
# 8178        1           0         1           0              0              0
# 8179        0           1         1           0              0              0
# 8180        1           1         1           0              0              0
# 8181        0           0         1           0              0              0
# 8182        0           1         1           0              0              0
# 8183        1           1         1           0              0              0
# 8184        1           1         1           0              0              0
# 8185        1           1         1           0              0              0
# 8186        1           1         1           0              0              0
# 8187        1           1         1           0              0              0
# 8188        0           0         1           0              0              0
# 8189        0           1         1           0              0              0
#
#       underdogRecord  prevFavoredRecord  prevUnderdogRecord  absLine
# 8174               0             0.8125              0.6250      7.5
# 8175               0             0.7500              0.3750     10.5
# 8176               0             0.5000              0.3750      6.0
# 8177               0             0.4375              0.8125      3.5
# 8178               0             0.4375              0.3750      6.0
# 8179               0             0.1250              0.1250      4.5
# 8180               0             0.6250              0.6250      3.0
# 8181               0             0.3125              0.4375      2.5
# 8182               0             0.6875              0.4375      3.5
# 8183               0             0.2500              0.6250      4.5
# 8184               0             0.6875              0.2500     11.5
# 8185               0             0.4375              0.3125      3.5
# 8186               0             0.6875              0.6875      5.0
# 8187               0             0.5000              0.5625      3.5
# 8188               0             0.6250              0.2500      4.5
# 8189               0             0.7500              0.4375      6.5
#
# [16 rows x 20 columns]

# %%
# run one year of rolling training, control width of training window w/ trainFreq
import runMadden
reload(runMadden)
reload(madden)

# need to be arrays
trainYears = [2012] #range(2008.2013) 
testYear = [2013]
trainFreq = 6

dd = runMadden.runSeasonRolling(trainYears,testYear,olookups,trainFreq)
dd
# Out:
# season 2013, week 1
# training data accuracy =  0.6875
# season 2013, week 2
# training data accuracy =  0.6875
# season 2013, week 3
# training data accuracy =  0.6875
# season 2013, week 4
# training data accuracy =
#  0.6875
# season 2013, week 5
# training data accuracy =  0.6875
# season 2013, week 6
# training data accuracy =  0.684684684685
# season 2013, week 7
# training data accuracy =
#  0.684684684685
# season 2013, week 8
# training data accuracy =  0.684684684685
# season 2013, week 9
# training data accuracy =  0.684684684685
# season 2013, week 10
# training data accuracy =
#  0.684684684685
# season 2013, week 11
# training data accuracy =  0.684684684685
# season 2013, week 12
# training data accuracy =  0.712918660287
# season 2013, week 13
# training data accuracy =
#  0.712918660287
# season 2013, week 14
# training data accuracy =  0.712918660287
# season 2013, week 15
# training data accuracy =  0.712918660287
# season 2013, week 16
# training data accuracy =  0.712918660287
# season 2013, week 17
# training data accuracy =  0.712918660287
#       season  lineScore  probaScore1  probaScore2  probaScore3  train  \
# 2013    2013       1655         1676         1641         1653   2012
#
#       trainFreq
# 2013          6
#
# [1 rows x 7 columns]

# %%
# loop over years to test trainFreq

reload(runMadden)
reload(madden)

ddd = None
for y in range(2008,2013):
    trainYears = [y]
    testYear = [y+1]
    trainFreq = 20
    dd = runMadden.runSeasonRolling(trainYears,testYear,olookups,trainFreq)
    if ddd is None:
        ddd = dd
    else:
        ddd = ddd.append(dd)
        
ddd
# Out:
# season 2009, week 1
# training data accuracy =  0.6875
# season 2009, week 2
# training data accuracy =  0.6875
# season 2009, week 3
# training data accuracy =  0.6875
# season 2009, week 4
# training data accuracy =
#  0.6875
# season 2009, week 5
# training data accuracy =  0.6875
# season 2009, week 6
# training data accuracy =  0.6875
# season 2009, week 7
# training data accuracy =  0.6875
# season 2009, week 8
# training data accuracy =  0.6875
# season 2009, week 9
# training data accuracy =  0.6875
# season 2009, week 10
# training data accuracy =  0.6875
# season 2009, week 11
# training data accuracy =
#  0.6875
# season 2009, week 12
# training data accuracy =  0.6875
# season 2009, week 13
# training data accuracy =  0.6875
# season 2009, week 14
# training data accuracy =  0.6875
# season 2009, week 15
# training data accuracy =  0.6875
# season 2009, week 16
# training data accuracy =  0.6875
# season 2009, week 17
# training data accuracy =  0.6875
# season 2010, week 1
# training data accuracy =  0.7265625
# season 2010, week 2
# training data accuracy =  0.7265625
# season 2010, week 3
# training data accuracy =  0.7265625
# season 2010, week 4
# training data accuracy =  0.7265625
# season 2010, week 5
# training data accuracy =  0.7265625
# season 2010, week 6
# training data accuracy =  0.7265625
# season 2010, week 7
# training data accuracy =  0.7265625
# season 2010, week 8
# training data accuracy =  0.7265625
# season 2010, week 9
# training data accuracy =  0.7265625
# season 2010, week 10
# training data accuracy =  0.7265625
# season 2010, week 11
# training data accuracy =  0.7265625
# season 2010, week 12
# training data accuracy =  0.7265625
# season 2010, week 13
# training data accuracy =  0.7265625
# season 2010, week 14
# training data accuracy =  0.7265625
# season 2010, week 15
# training data accuracy =  0.7265625
# season 2010, week 16
# training data accuracy =
#  0.7265625
# season 2010, week 17
# training data accuracy =  0.7265625
# season 2011, week 1
# training data accuracy =  0.6796875
# season 2011, week 2
# training data accuracy =  0.6796875
# season 2011, week 3
# training data accuracy =  0.6796875
# season 2011, week 4
# training data accuracy =
#  0.6796875
# season 2011, week 5
# training data accuracy =  0.6796875
# season 2011, week 6
# training data accuracy =  0.6796875
# season 2011, week 7
# training data accuracy =  0.6796875
# season 2011, week 8
# training data accuracy =  0.6796875
# season 2011, week 9
# training data accuracy =  0.6796875
# season 2011, week 10
# training data accuracy =  0.6796875
# season 2011, week 11
# training data accuracy =
#  0.6796875
# season 2011, week 12
# training data accuracy =  0.6796875
# season 2011, week 13
# training data accuracy =  0.6796875
# season 2011, week 14
# training data accuracy =  0.6796875
# season 2011, week 15
# training data accuracy =  0.6796875
# season 2011, week 16
# training data accuracy =  0.6796875
# season 2011, week 17
# training data accuracy =  0.6796875
# season 2012, week 1
# training data accuracy =  0.71875
# season 2012, week 2
# training data accuracy =  0.71875
# season 2012, week 3
# training data accuracy =  0.71875
# season 2012, week 4
# training data accuracy =
#  0.71875
# season 2012, week 5
# training data accuracy =  0.71875
# season 2012, week 6
# training data accuracy =  0.71875
# season 2012, week 7
# training data accuracy =  0.71875
# season 2012, week 8
# training data accuracy =  0.71875
# season 2012, week 9
# training data accuracy =  0.71875
# season 2012, week 10
# training data accuracy =  0.71875
# season 2012, week 11
# training data accuracy =
#  0.71875
# season 2012, week 12
# training data accuracy =  0.71875
# season 2012, week 13
# training data accuracy =  0.71875
# season 2012, week 14
# training data accuracy =
#  0.71875
# season 2012, week 15
# training data accuracy =  0.71875
# season 2012, week 16
# training data accuracy =  0.71875
# season 2012, week 17
# training data accuracy =  0.71875
# season 2013, week 1
# training data accuracy =  0.6875
# season 2013, week 2
# training data accuracy =  0.6875
# season 2013, week 3
# training data accuracy =  0.6875
# season 2013, week 4
# training data accuracy =  0.6875
# season 2013, week 5
# training data accuracy =  0.6875
# season 2013, week 6
# training data accuracy =  0.6875
# season 2013, week 7
# training data accuracy =  0.6875
# season 2013, week 8
# training data accuracy =  0.6875
# season 2013, week 9
# training data accuracy =  0.6875
# season 2013, week 10
# training data accuracy =  0.6875
# season 2013, week 11
# training data accuracy =  0.6875
# season 2013, week 12
# training data accuracy =  0.6875
# season 2013, week 13
# training data accuracy =  0.6875
# season 2013, week 14
# training data accuracy =  0.6875
# season 2013, week 15
# training data accuracy =  0.6875
# season 2013, week 16
# training data accuracy =  0.6875
# season 2013, week 17
# training data accuracy =  0.6875
#       season  lineScore  probaScore1  probaScore2  probaScore3  train  \
# 2009    2009       1708         1731         1720         1715   2008
# 2010    2010       1593         1615         1638         1624   2009
# 2011    2011       1691         1687         1676         1672   2010
# 2012    2012       1623         1622         1641         1628   2011
# 2013    2013       1655         1679         1667         1652   2012
#
#       trainFreq
# 2009         20
# 2010         20
# 2011         20
# 2012         20
# 2013         20
#
# [5 rows x 7 columns]

# %%
# diagnostics ... weekly outcomes
g = dfAll.groupby('gameWeek')['lineScore','probaScore1','probaScore2','probaScore3'].sum()
print(g)
g.sum()
# Out:
#           lineScore  probaScore1  probaScore2  probaScore3
# gameWeek
# 1               103          111          109          108
# 2               114          111          106          109
# 3                87           96           91           97
# 4                94           94           96          100
# 5                77           76           77           85
# 6               114          115          103           93
# 7                97           92           97           98
# 8               117          116          115          116
# 9                79           84           92           97
# 10               80           83           81           76
# 11              106          111          116          117
# 12               63           59           47           45
# 13              108          107          106          101
# 14              119          127          124          111
# 15               80           79           81           80
# 16               93           92          100           93
# 17              124          126          126          126
#
# [17 rows x 4 columns]
# lineScore      1655
# probaScore1    1679
# probaScore2    1667
# probaScore3    1652
# dtype: float64

# %%
dd
# Out:
#       season  lineScore  probaScore1  probaScore2  probaScore3
# 2013    2013       1655         1679         1667         1652
#
# [1 rows x 5 columns]

# %%
5 % 2
# Out:
# 1
