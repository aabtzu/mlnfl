# %%
import os
homeDir = os.environ['HOME'] + '/'
codeDir = homeDir + 'sandbox/nfl/'
bucketRoot = 'nfl/'
dataRoot = codeDir + "data/" 
os.chdir(codeDir)

# %%
# lookup files
import lookup
lookupFiles = { 'teams' : {'file': 'nflTeams.csv' },
                'seasons' : {'file': 'seasons.csv' },
               }

lookupDir = dataRoot+'lookup/'
olookups = lookup.Lookup(lookupDir, lookupFiles)

#olookups.ldict['seasons'].keys()

# %%
reload(data)

season = '2012'
dfAllGames = data.readGames(dataRoot,season)
dfAllTeams = data.seasonRecord(dfAllGames,olookups)
dfAllGames = data.processGames(dfAllGames, dfAllTeams, olookups, season)
logreg = data.runML(dfAllGames)

# use different test set 
season = '2013'
dfGamesTest = data.readGames(dataRoot,season)
dfTeamsTest = data.seasonRecord(dfGamesTest,olookups)
dfGamesTest = data.processGames(dfGamesTest, dfTeamsTest, olookups, season)


dfPredict = data.predictGames(dfGamesTest,logreg)
dfAll = data.rankGames(dfPredict)


dispCols = ['gameWeek','Visitor','Home Team','Line','predict','predict_proba','Visitor Score','Home Score','favoredWin','lineGuess','probaGuess', 'lineScore','probaScore']
dfAll[dfAll.gameWeek ==4][dispCols]
# Out:
# training data accuracy =  0.640625
#           lineScore  probaScore
# gameWeek
# 1               103         102
# 2               114         109
# 3                88         100
# 4                93          95
# 5                76          76
# 6               113         114
# 7                96          93
# 8               117         117
# 9                79          81
# 10               80          80
# 11              109         108
# 12               62          61
# 13              108         110
# 14              121         126
# 15               79          83
# 16               94          95
# 17              124         125
#
# [17 rows x 2 columns]
# lineScore     1656
# probaScore    1675
# dtype: float64
#     gameWeek               Visitor             Home Team  Line  predict  \
# 58         4        Dallas Cowboys    San Diego Chargers  -1.5        0
# 53         4      Seattle Seahawks        Houston Texans  -2.0        0
# 54         4     Arizona Cardinals  Tampa Bay Buccaneers   2.5        0
# 55         4         Chicago Bears         Detroit Lions   2.5        0
# 49         4   Pittsburgh Steelers     Minnesota Vikings  -3.0        0
# 61         4  New England Patriots       Atlanta Falcons   3.0        0
# 57         4         New York Jets      Tennessee Titans   3.5        0
# 59         4   Washington Redskins       Oakland Raiders  -4.0        0
# 48         4   San Francisco 49ers         St Louis Rams  -4.0        1
# 50         4      Baltimore Ravens         Buffalo Bills  -4.0        1
# 51         4    Cincinnati Bengals      Cleveland Browns  -4.5        1
# 56         4       New York Giants    Kansas City Chiefs   4.5        1
# 62         4        Miami Dolphins    New Orleans Saints   7.5        1
# 52         4    Indianapolis Colts  Jacksonville Jaguars  -9.5        1
# 60         4   Philadelphia Eagles        Denver Broncos  11.5        1
#
#     predict_proba  Visitor Score  Home Score  favoredWin  lineGuess  \
# 58       0.399823             21          30           0          2
# 53       0.424970             23          20           1          3
# 54       0.370376             13          10           0          4
# 55       0.410295             32          40           1          5
# 49       0.430528             27          34           0          6
# 61       0.323312             30          23           0          7
# 57       0.497196             13          38           1          8
# 59       0.417479             24          14           1          9
# 48       0.542868             35          11           1         10
# 50       0.559637             20          23           0         11
# 51       0.642788              6          17           0         12
# 56       0.760810              7          31           1         13
# 62       0.730435             17          38           1         14
# 52       0.899444             37           3           1         15
# 60       0.934247             20          52           1         16
#
#     probaGuess  lineScore  probaScore
# 58           4          0           0
# 53           7          3           7
# 54           3          0           0
# 55           5          5           5
# 49           8          0           0
# 61           2          0           0
# 57           9          8           9
# 59           6          9           6
# 48          10         10          10
# 50          11          0           0
# 51          12          0           0
# 56          14         13          14
# 62          13         14          13
# 52          15         15          15
# 60          16         16          16
#
# [15 rows x 13 columns]

# %%
dfAllGames.columns
# Out:
# Index([u'Date', u'Visitor', u'Visitor Score', u'Home Team', u'Home Score', u'Line', u'Total Line', u'favoredHomeGame', u'divisionGame', u'homeWin', u'favoredWin', u'gameWeek', u'homeRecord', u'visitorRecord', u'favoredRecord', u'underdogRecord', u'absLine'], dtype='object')

# %%
#plot(dfAllGames.favoredRecord[nWin]*dfAllGames.gameWeek[nWin],abs(dfAllGames.Line[nWin]),'ro')
#plot(dfAllGames.favoredRecord[nWin],abs(dfAllGames.Line[nWin]),'bo')
#plot(dfAllGames.favoredRecord[nLose],abs(dfAllGames.Line[nLose]),'ro')

plot(dfAllGames.favoredRecord[nWin],dfAllGames.underdogRecord[nWin],'bo')
plot(dfAllGames.favoredRecord[nLose],dfAllGames.underdogRecord[nLose],'ro')

# %%
# print out season record
cols = ['team','gamesWon','gamesLost']
dfAllTeams[dfAllTeams.gamesPlayed==16][cols]
# Out:
#                      team  gamesWon  gamesLost
# 247        Dallas Cowboys         8          8
# 244    Indianapolis Colts        11          5
# 246   Philadelphia Eagles         4         12
# 240         Buffalo Bills         6         10
# 247   Washington Redskins        10          6
# 241  New England Patriots        12          4
# 245  Jacksonville Jaguars         2         14
# 241        Miami Dolphins         7          9
# 255         St Louis Rams         7          9
# 250       Atlanta Falcons        13          3
# 254   San Francisco 49ers        11          5
# 251     Carolina Panthers         7          9
# 255      Seattle Seahawks        11          5
# 243   Pittsburgh Steelers         8          8
# 242    Cincinnati Bengals        10          6
# 253    San Diego Chargers         7          9
# 248         Chicago Bears        10          6
# 250  Tampa Bay Buccaneers         7          9
# 254     Arizona Cardinals         5         11
# 249     Minnesota Vikings        10          6
# 251    New Orleans Saints         7          9
# 252    Kansas City Chiefs         2         14
# 242      Baltimore Ravens        10          6
# 253       Oakland Raiders         4         12
# 243      Cleveland Browns         5         11
# 244        Houston Texans        12          4
# 240         New York Jets         6         10
# 245      Tennessee Titans         6         10
# 248         Detroit Lions         4         12
# 252        Denver Broncos        13          3
# 246       New York Giants         9          7
# 249     Green Bay Packers        11          5
#
# [32 rows x 3 columns]
