# %% [markdown]
# ## nfl lines machine learning project
#
#
# source data for historical spreads and game scores
# http://www.repole.com/sun4cast/data.html

# %%
# define source and data directories
import os
homeDir = os.environ['HOME'] + '/'

codeDir = homeDir + 'repos/mlkaggle/nfl/'
codeDir = homeDir + 'sandbox/nfl/'
dataRoot = codeDir + "data/" 
os.chdir(codeDir)

dataRoot
# Out:
# '/Users/amit.bhattacharyya/sandbox/nfl/data/'

# %%
# lookup files
import lookup
lookupFiles = { 'teams' : {'file': 'nflTeams.csv' },
                'seasons' : {'file': 'seasons.csv' },
               }

lookupDir = dataRoot+'lookup/'
olookups = lookup.Lookup(lookupDir, lookupFiles)

#olookups.ldict['seasons'].keys()

# %%
import data
reload(data)

# training data set
season = '2009'
# read data file
dfAllGames = data.readGames(dataRoot,season)
# compile season record for all teams
dfAllTeams = data.seasonRecord(dfAllGames,olookups)
# apply season records and compute other fields for all games
dfAllGames = data.processGames(dfAllGames, dfAllTeams, olookups, season)
# run the logistic regression
logreg = data.runML(dfAllGames)

# use different test set 
season = '2013'
dfGamesTest = data.readGames(dataRoot,season)
dfTeamsTest = data.seasonRecord(dfGamesTest,olookups)
dfGamesTest = data.processGames(dfGamesTest, dfTeamsTest, olookups, season)

# apply results of logistic regression to the test set
dfPredict = data.predictGames(dfGamesTest,logreg)
dfAll = data.rankGames(dfPredict)

# display details for a single week
dispWeek = 1
dispCols = ['gameWeek','Visitor','Home Team','Line','predict_proba','Visitor Score','Home Score','favoredWin','predictWin','lineGuess','probaGuess', 'lineScore','probaScore1']
dfAll[dfAll.gameWeek == dispWeek][dispCols]
# Out:
# training data accuracy =  0.734375
#           lineScore  probaScore1  probaScore2  probaScore3
# gameWeek
# 1               103           99           99           99
# 2               114           99           96           89
# 3                88          102          101          104
# 4                92           88           82           86
# 5                76           70           77           79
# 6               113          112          107          102
# 7                97           91           92           90
# 8               117          117          121          121
# 9                79           85           89           91
# 10               80           79           67           66
# 11              108          104          102          102
# 12               62           70           77           78
# 13              107          108          112          105
# 14              120          130          131          129
# 15               79           85           86           86
# 16               93           94           97           97
# 17              124          127          126          128
#
# [17 rows x 4 columns]
# lineScore      1652
# probaScore1    1660
# probaScore2    1662
# probaScore3    1652
# dtype: float64
#     gameWeek               Visitor             Home Team  Line  predict_proba  \
# 7          1        Miami Dolphins      Cleveland Browns   2.5       0.596299
# 6          1    Cincinnati Bengals         Chicago Bears   3.0       0.608553
# 8          1      Seattle Seahawks     Carolina Panthers  -3.5       0.567479
# 3          1       Atlanta Falcons    New Orleans Saints   3.5       0.530237
# 11         1     Arizona Cardinals         St Louis Rams   3.5       0.530237
# 13         1       New York Giants        Dallas Cowboys   3.5       0.530237
# 5          1    Kansas City Chiefs  Jacksonville Jaguars  -4.5       0.592402
# 9          1     Minnesota Vikings         Detroit Lions   4.5       0.555625
# 14         1   Philadelphia Eagles   Washington Redskins   4.5       0.555625
# 12         1     Green Bay Packers   San Francisco 49ers   5.0       0.656084
# 4          1  Tampa Bay Buccaneers         New York Jets  -6.0       0.628876
# 2          1      Tennessee Titans   Pittsburgh Steelers   6.0       0.678791
# 15         1        Houston Texans    San Diego Chargers  -6.5       0.640737
# 0          1      Baltimore Ravens        Denver Broncos   7.5       0.711303
# 1          1  New England Patriots         Buffalo Bills -10.5       0.649441
# 10         1       Oakland Raiders    Indianapolis Colts  11.5       0.787687
#
#     Visitor Score  Home Score  favoredWin  predictWin  lineGuess  probaGuess  \
# 7              23          10           0           0          1           8
# 6              21          24           1           1          2           9
# 8              12           7           1           1          3           6
# 3              17          23           1           1          4           1
# 11             24          27           1           1          5           2
# 13             31          36           1           1          6           3
# 5              28           2           1           1          7           7
# 9              24          34           1           1          8           4
# 14             33          27           0           0          9           5
# 12             28          34           1           1         10          13
# 4              17          18           0           0         11          10
# 2              16           9           0           0         12          14
# 15             31          28           1           1         13          11
# 0              27          49           1           1         14          15
# 1              23          21           1           1         15          12
# 10             17          21           1           1         16          16
#
#     lineScore  probaScore1
# 7           0            0
# 6           2            9
# 8           3            6
# 3           4            1
# 11          5            2
# 13          6            3
# 5           7            7
# 9           8            4
# 14          0            0
# 12         10           13
# 4           0            0
# 2           0            0
# 15         13           11
# 0          14           15
# 1          15           12
# 10         16           16
#
# [16 rows x 13 columns]

# %%
reload(data)
dfPredict = data.predictGames(dfGamesTest,logreg)
dfPredict.predict_proba_abs
# Out:
# 0     0.175112
# 1     0.148637
# 2     0.145864
# 3     0.150176
# 4     0.003706
# 5     0.036266
# 6     0.084171
# 7     0.073567
# 8     0.057819
# 9     0.169696
# 10    0.246377
# 11    0.150176
# 12    0.125723
# 13    0.150176
# 14    0.169696
# ...
# 241    0.002317
# 242    0.299807
# 243    0.328143
# 244    0.235742
# 245    0.291610
# 246    0.393474
# 247    0.143867
# 248    0.222009
# 249    0.030197
# 250    0.340465
# 251    0.384906
# 252    0.336714
# 253    0.112860
# 254    0.307402
# 255    0.397225
# Name: predict_proba_abs, Length: 256, dtype: float64

# %%
# diagnotics ... display all columns
dfAllGames.columns
# Out:
# Index([u'Date', u'Visitor', u'Visitor Score', u'Home Team', u'Home Score', u'Line', u'Total Line', u'favoredHomeGame', u'divisionGame', u'homeWin', u'favoredWin', u'gameWeek', u'homeRecord', u'visitorRecord', u'favoredRecord', u'underdogRecord', u'absLine'], dtype='object')

# %%
# diagnostics ... plot outcomes of games
nWin = dfAllGames.favoredWin.index.tolist()
nLose = dfAllGames[dfAllGames['favoredWin'] == 0].index.tolist()

plot(dfAllGames.favoredRecord[nWin],dfAllGames.underdogRecord[nWin],'bx')
plot(dfAllGames.favoredRecord[nLose],dfAllGames.underdogRecord[nLose],'rx')

# %%
# diagnostics ... print out end of season record
cols = ['team','gamesWon','gamesLost']
dfAllTeams[dfAllTeams.gamesPlayed==16][cols].sort('gamesWon',ascending=False)
# Out:
#                      team  gamesWon  gamesLost
# 252        Denver Broncos        13          3
# 255      Seattle Seahawks        13          3
# 250  New England Patriots        12          4
# 253   San Francisco 49ers        12          4
# 240     Carolina Panthers        12          4
# 246    Indianapolis Colts        11          5
# 254    Kansas City Chiefs        11          5
# 245    Cincinnati Bengals        11          5
# 251    New Orleans Saints        11          5
# 247   Philadelphia Eagles        10          6
# 253     Arizona Cardinals        10          6
# 254    San Diego Chargers         9          7
# 241         Chicago Bears         8          8
# 248        Miami Dolphins         8          8
# 241     Green Bay Packers         8          8
# 245      Baltimore Ravens         8          8
# 248         New York Jets         8          8
# 247        Dallas Cowboys         8          8
# 243   Pittsburgh Steelers         8          8
# 244       New York Giants         7          9
# 255         St Louis Rams         7          9
# 249         Detroit Lions         7          9
# 242      Tennessee Titans         7          9
# 250         Buffalo Bills         6         10
# 249     Minnesota Vikings         5         11
# 243      Cleveland Browns         4         12
# 252       Oakland Raiders         4         12
# 246  Jacksonville Jaguars         4         12
# 251  Tampa Bay Buccaneers         4         12
# 240       Atlanta Falcons         4         12
# 244   Washington Redskins         3         13
# 242        Houston Texans         2         14
#
# [32 rows x 3 columns]
