# %% [markdown]
# ## nfl lines machine learning project
#
#
# source data for historical spreads and game scores
# http://www.repole.com/sun4cast/data.html

# %%
# define source and data directories
import os
homeDir = os.environ['HOME'] + '/'

codeDir = homeDir + 'repos/mlkaggle/nfl/'
codeDir = homeDir + 'sandbox/nfl/'
dataRoot = codeDir + "data/" 
os.chdir(codeDir)

dataRoot
# Out:
# '/Users/amit.bhattacharyya/sandbox/nfl/data/'

# %%
# lookup files
import lookup
lookupFiles = { 'teams' : {'file': 'nflTeams.csv' },
                'seasons' : {'file': 'seasons.csv' },
               }

lookupDir = dataRoot+'lookup/'
olookups = lookup.Lookup(lookupDir, lookupFiles)

# print out for diagnostics
#olookups.ldict['seasons'].keys()

# %%
import data
reload(data)

# training data set
season = 2012
seasonStr = str(season)
prevSeasonStr = str(season-1)
# read data files
dfAllGames = data.readGames(dataRoot,seasonStr)
dfPrevGames = data.readGames(dataRoot,prevSeasonStr)

# compile season record for all teams
dfAllTeams = data.seasonRecord(dfAllGames,olookups)
dfPrevTeams = data.seasonRecord(dfPrevGames,olookups)

# apply season records and compute other fields for all games
dfAllGames = data.processGames(dfAllGames, dfAllTeams, olookups, seasonStr, dfPrevTeams)

# define indep variables for logistic regression
features = ['favoredRecord','underdogRecord',
            'prevFavoredRecord','prevUnderdogRecord',
            'gameWeek',
            'absLine',
            'divisionGame',
            'favoredHomeGame',
            ]
# run the logistic regression
logreg = data.runML(dfAllGames,features)

# use different test set 
seasonTest = 2013
seasonTestStr = str(seasonTest)
prevSeasonTestStr = str(seasonTest-1)

dfGamesTest = data.readGames(dataRoot,seasonTestStr)
dfPrevGamesTest = data.readGames(dataRoot,prevSeasonTestStr)

dfTeamsTest = data.seasonRecord(dfGamesTest,olookups)
dfPrevTeamsTest = data.seasonRecord(dfPrevGamesTest,olookups)

dfGamesTest = data.processGames(dfGamesTest, dfTeamsTest, olookups, seasonTestStr, dfPrevTeamsTest)

# apply results of logistic regression to the test set
dfPredict = data.predictGames(dfGamesTest,logreg,features)

# apply ranking logic and determine scoring outcomes for league
dfAll = data.rankGames(dfPredict,olookups,seasonTestStr)
# Out:
# training data accuracy =  0.6875
#           lineScore  probaScore1  probaScore2  probaScore3
# gameWeek
# 1               104          111          109          108
# 2               114          111          106          109
# 3                88           96           91           97
# 4                94           94           96          100
# 5                76           76           77           85
# 6               113          115          103           93
# 7                97           92           97           98
# 8               117          116          115          116
# 9                80           84           92           97
# 10               80           83           81           76
# 11              109          111          116          117
# 12               62           59           47           45
# 13              109          107          106          101
# 14              120          127          124          111
# ...

# %%
# display details for a single week
dispWeek = 1
dispCols = ['gameWeek','Visitor','Home Team','prevFavoredRecord','Line','predict_proba','Visitor Score','Home Score','favoredWin','predictWin','lineGuess','probaGuess', 'lineScore','probaScore1']
dfAll[dfAll.gameWeek == dispWeek][dispCols]
# Out:
#     gameWeek               Visitor             Home Team  prevFavoredRecord  \
# 7          1        Miami Dolphins      Cleveland Browns             0.3125
# 6          1    Cincinnati Bengals         Chicago Bears             0.6250
# 8          1      Seattle Seahawks     Carolina Panthers             0.6875
# 11         1     Arizona Cardinals         St Louis Rams             0.4375
# 13         1       New York Giants        Dallas Cowboys             0.5000
# 3          1       Atlanta Falcons    New Orleans Saints             0.4375
# 5          1    Kansas City Chiefs  Jacksonville Jaguars             0.1250
# 14         1   Philadelphia Eagles   Washington Redskins             0.6250
# 9          1     Minnesota Vikings         Detroit Lions             0.2500
# 12         1     Green Bay Packers   San Francisco 49ers             0.6875
# 4          1  Tampa Bay Buccaneers         New York Jets             0.4375
# ...

# %%
# diagnostics ... display all columns
dfAllGames.columns
# Out:
# Index([u'Date', u'Visitor', u'Visitor Score', u'Home Team', u'Home Score', u'Line', u'Total Line', u'favoredHomeGame', u'divisionGame', u'homeWin', u'favoredWin', u'gameWeek', u'homeRecord', u'visitorRecord', u'favoredRecord', u'underdogRecord', u'prevFavoredRecord', u'prevUnderdogRecord', u'absLine'], dtype='object')

# %%
# diagnostics ... plot outcomes of games
nWin = dfAllGames.favoredWin.index.tolist()
nLose = dfAllGames[dfAllGames['favoredWin'] == 0].index.tolist()

plot(dfAllGames.favoredRecord[nWin],dfAllGames.underdogRecord[nWin],'bx')
plot(dfAllGames.favoredRecord[nLose],dfAllGames.underdogRecord[nLose],'rx')

# %%
# diagnostics ... print out end of season record
dft = dfPrevTeams

cols = ['team','gamesWon','gamesLost']
print dft[dft.gamesPlayed==16][cols].sort('gamesWon',ascending=False)

reload(data)

teams = dft.team.unique()
print teams
t = teams[12]
w = 17
rr = data.getRecord(dft,t,w)
print t, rr
11/16.
# Out:
#                      team  gamesWon  gamesLost
# 244     Green Bay Packers        15          1
# 246    New Orleans Saints        13          3
# 242   San Francisco 49ers        13          3
# 252  New England Patriots        13          3
# 249   Pittsburgh Steelers        12          4
# 248      Baltimore Ravens        12          4
# 244         Detroit Lions        10          6
# 241       Atlanta Falcons        10          6
# 247        Houston Texans        10          6
# 248    Cincinnati Bengals         9          7
# 247      Tennessee Titans         9          7
# 245       New York Giants         9          7
# 251         New York Jets         8          8
# 240   Philadelphia Eagles         8          8
# 245        Dallas Cowboys         8          8
# 253       Oakland Raiders         8          8
# 243         Chicago Bears         8          8
# 255     Arizona Cardinals         8          8
# 253    San Diego Chargers         8          8
# ...

# %%
reload(data)
dfAll, ss = data.rankGames(dfPredict,olookups,seasonStr)
# Out:
# 1653
#           lineScore  probaScore1  probaScore2  probaScore3
# gameWeek
# 1               104          111          108          106
# 2               114          105          106          100
# 3                87          104          107          109
# 4                93           94          104           99
# 5                76           74           81           83
# 6               114          113          109          102
# 7                96           85           85           85
# 8               118          117          121          121
# 9                79           86           96           95
# 10               80           82           83           79
# 11              109          119          121          123
# 12               62           61           58           57
# 13              108          112          112          112
# 14              121          133          134          135
# 15               79           83           84           82
# ...
