# %%
import os
import pandas
import urllib2
import requests
import bs4

# %%
url = 'http://www.pro-football-reference.com/years/2016/games.htm'
r  = requests.get(url)
data = r.text

soup = bs4.BeautifulSoup(data)

# get the tables w/ the spreads
tt = soup.findAll("table")
# Out:
# /Users/amit/.virtualenvs/datascience/lib/python2.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 162 of the file /System/Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
dfs = pandas.read_html(str(tt[0]), )
df_scores = dfs[0]

week = 2
week_filter = df_scores.Week == str(week)
df_week = df_scores[week_filter]
df_week
# Out:
#    Week  Day          Date    Time            Winner/tie Unnamed: 5  \
# 17    2  Thu  September 15  8:26PM         New York Jets          @
# 18    2  Sun  September 18  1:02PM  New England Patriots        NaN
# 19    2  Sun  September 18  1:02PM      Tennessee Titans          @
# 20    2  Sun  September 18  1:02PM      Baltimore Ravens          @
# 21    2  Sun  September 18  1:02PM        Houston Texans        NaN
# 22    2  Sun  September 18  1:02PM   Pittsburgh Steelers        NaN
# 23    2  Sun  September 18  1:03PM     Carolina Panthers        NaN
# 24    2  Sun  September 18  1:03PM        Dallas Cowboys          @
# 25    2  Sun  September 18  1:03PM       New York Giants        NaN
# 26    2  Sun  September 18  1:05PM     Arizona Cardinals        NaN
# 27    2  Sun  September 18  4:08PM      Los Angeles Rams        NaN
# 28    2  Sun  September 18  4:25PM       Atlanta Falcons          @
# 29    2  Sun  September 18  4:25PM    San Diego Chargers        NaN
# 30    2  Sun  September 18  4:25PM        Denver Broncos        NaN
# 31    2  Sun  September 18  8:32PM     Minnesota Vikings        NaN
# 32    2  Mon  September 19  8:30PM   Philadelphia Eagles          @
#
#                Loser/tie Unnamed: 7 PtsW PtsL YdsW TOW YdsL TOL
# 17         Buffalo Bills   boxscore   37   31  493   1  393   1
# 18        Miami Dolphins   boxscore   31   24  465   1  459   4
# 19         Detroit Lions   boxscore   16   15  363   1  375   1
# 20      Cleveland Browns   boxscore   25   20  382   2  387   2
# 21    Kansas City Chiefs   boxscore   19   12  351   2  291   3
# 22    Cincinnati Bengals   boxscore   24   16  374   2  412   2
# 23   San Francisco 49ers   boxscore   46   27  529   4  302   3
# 24   Washington Redskins   boxscore   27   23  380   1  432   1
# 25    New Orleans Saints   boxscore   16   13  417   3  288   0
# 26  Tampa Bay Buccaneers   boxscore   40    7  416   0  306   5
# 27      Seattle Seahawks   boxscore    9    3  283   0  306   1
# 28       Oakland Raiders   boxscore   35   28  528   1  454   0
# 29  Jacksonville Jaguars   boxscore   38   14  357   1  388   3
# 30    Indianapolis Colts   boxscore   34   20  400   1  253   2
# 31     Green Bay Packers   boxscore   17   14  284   1  263   3
# 32         Chicago Bears   boxscore   29   14  280   0  284   3

# %%
winner_col = 'Winner/tie'
loser_col = 'Loser/tie'
winner_pts_col = 'PtsW'
loser_pts_col = 'PtsL'
home_col = 'Unnamed: 5'

# means that winner was away team, loser was home team
away_filter = df_week[home_col] == '@'

# populate these new cols
new_cols = ['home_pts', 'away_pts', 'home_team', 'away_team']
for cc in new_cols:
    df_week[cc] = None
    
df_week.loc[~away_filter, 'home_team']  = df_week.loc[~away_filter, winner_col]
df_week.loc[away_filter, 'home_team']  = df_week.loc[away_filter, loser_col]
df_week.loc[~away_filter, 'away_team']  = df_week.loc[~away_filter, loser_col]
df_week.loc[away_filter, 'away_team']  = df_week.loc[away_filter, winner_col]

df_week.loc[~away_filter, 'home_pts']  = df_week.loc[~away_filter, winner_pts_col]
df_week.loc[away_filter, 'home_pts']  = df_week.loc[away_filter, loser_pts_col]
df_week.loc[~away_filter, 'away_pts']  = df_week.loc[~away_filter, loser_pts_col]
df_week.loc[away_filter, 'away_pts']  = df_week.loc[away_filter, winner_pts_col]
# Out:
# /Users/amit/.virtualenvs/datascience/lib/python2.7/site-packages/ipykernel/__main__.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/amit/.virtualenvs/datascience/lib/python2.7/site-packages/ipykernel/__main__.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/amit/.virtualenvs/datascience/lib/python2.7/site-packages/ipykernel/__main__.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/amit/.virtualenvs/datascience/lib/python2.7/site-packages/ipykernel/__main__.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/amit/.virtualenvs/datascience/lib/python2.7/site-packages/ipykernel/__main__.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/amit/.virtualenvs/datascience/lib/python2.7/site-packages/ipykernel/__main__.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/amit/.virtualenvs/datascience/lib/python2.7/site-packages/ipykernel/__main__.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/amit/.virtualenvs/datascience/lib/python2.7/site-packages/ipykernel/__main__.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/amit/.virtualenvs/datascience/lib/python2.7/site-packages/ipykernel/__main__.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_week
# Out:
#    Week  Day          Date    Time            Winner/tie Unnamed: 5  \
# 17    2  Thu  September 15  8:26PM         New York Jets          @
# 18    2  Sun  September 18  1:02PM  New England Patriots        NaN
# 19    2  Sun  September 18  1:02PM      Tennessee Titans          @
# 20    2  Sun  September 18  1:02PM      Baltimore Ravens          @
# 21    2  Sun  September 18  1:02PM        Houston Texans        NaN
# 22    2  Sun  September 18  1:02PM   Pittsburgh Steelers        NaN
# 23    2  Sun  September 18  1:03PM     Carolina Panthers        NaN
# 24    2  Sun  September 18  1:03PM        Dallas Cowboys          @
# 25    2  Sun  September 18  1:03PM       New York Giants        NaN
# 26    2  Sun  September 18  1:05PM     Arizona Cardinals        NaN
# 27    2  Sun  September 18  4:08PM      Los Angeles Rams        NaN
# 28    2  Sun  September 18  4:25PM       Atlanta Falcons          @
# 29    2  Sun  September 18  4:25PM    San Diego Chargers        NaN
# 30    2  Sun  September 18  4:25PM        Denver Broncos        NaN
# 31    2  Sun  September 18  8:32PM     Minnesota Vikings        NaN
# 32    2  Mon  September 19  8:30PM   Philadelphia Eagles          @
#
#                Loser/tie Unnamed: 7 PtsW PtsL YdsW TOW YdsL TOL home_pts  \
# 17         Buffalo Bills   boxscore   37   31  493   1  393   1       31
# 18        Miami Dolphins   boxscore   31   24  465   1  459   4       31
# 19         Detroit Lions   boxscore   16   15  363   1  375   1       15
# 20      Cleveland Browns   boxscore   25   20  382   2  387   2       20
# 21    Kansas City Chiefs   boxscore   19   12  351   2  291   3       19
# 22    Cincinnati Bengals   boxscore   24   16  374   2  412   2       24
# 23   San Francisco 49ers   boxscore   46   27  529   4  302   3       46
# 24   Washington Redskins   boxscore   27   23  380   1  432   1       23
# 25    New Orleans Saints   boxscore   16   13  417   3  288   0       16
# 26  Tampa Bay Buccaneers   boxscore   40    7  416   0  306   5       40
# 27      Seattle Seahawks   boxscore    9    3  283   0  306   1        9
# 28       Oakland Raiders   boxscore   35   28  528   1  454   0       28
# 29  Jacksonville Jaguars   boxscore   38   14  357   1  388   3       38
# 30    Indianapolis Colts   boxscore   34   20  400   1  253   2       34
# 31     Green Bay Packers   boxscore   17   14  284   1  263   3       17
# 32         Chicago Bears   boxscore   29   14  280   0  284   3       14
#
#    away_pts             home_team             away_team
# 17       37         Buffalo Bills         New York Jets
# 18       24  New England Patriots        Miami Dolphins
# 19       16         Detroit Lions      Tennessee Titans
# 20       25      Cleveland Browns      Baltimore Ravens
# 21       12        Houston Texans    Kansas City Chiefs
# 22       16   Pittsburgh Steelers    Cincinnati Bengals
# 23       27     Carolina Panthers   San Francisco 49ers
# 24       27   Washington Redskins        Dallas Cowboys
# 25       13       New York Giants    New Orleans Saints
# 26        7     Arizona Cardinals  Tampa Bay Buccaneers
# 27        3      Los Angeles Rams      Seattle Seahawks
# 28       35       Oakland Raiders       Atlanta Falcons
# 29       14    San Diego Chargers  Jacksonville Jaguars
# 30       20        Denver Broncos    Indianapolis Colts
# 31       14     Minnesota Vikings     Green Bay Packers
# 32       29         Chicago Bears   Philadelphia Eagles

# %%
# read in the master lines file
codeDir = "".join([os.environ['MLNFL_ROOT'], os.path.sep])
path_to_lines = codeDir + "data/lines/"
lines_file = path_to_lines + "nflAllLines.csv"

df_lines = pandas.read_csv(lines_file)
df_lines.Date = pandas.to_datetime(df_lines.Date)
df_lines
# Out:
#            Date               Visitor  Visitor Score             Home Team  \
# 0    1978-09-02       New York Giants           19.0  Tampa Bay Buccaneers
# 1    1978-09-03     Green Bay Packers           13.0         Detroit Lions
# 2    1978-09-03        Houston Oilers           14.0       Atlanta Falcons
# 3    1978-09-03    Kansas City Chiefs           24.0    Cincinnati Bengals
# 4    1978-09-03        Miami Dolphins           20.0         New York Jets
# 5    1978-09-03       Oakland Raiders            6.0        Denver Broncos
# 6    1978-09-03   Pittsburgh Steelers           28.0         Buffalo Bills
# 7    1978-09-03      Los Angeles Rams           16.0   Philadelphia Eagles
# 8    1978-09-03    San Diego Chargers           24.0      Seattle Seahawks
# 9    1978-09-03   San Francisco 49ers            7.0      Cleveland Browns
# 10   1978-09-03    St Louis Cardinals           10.0         Chicago Bears
# 11   1978-09-03     Minnesota Vikings           24.0    New Orleans Saints
# 12   1978-09-03   Washington Redskins           16.0  New England Patriots
# 13   1978-09-04       Baltimore Colts            0.0        Dallas Cowboys
# 14   1978-09-09         Detroit Lions           15.0  Tampa Bay Buccaneers
# 15   1978-09-10       Atlanta Falcons            0.0      Los Angeles Rams
# 16   1978-09-10         Chicago Bears           16.0   San Francisco 49ers
# 17   1978-09-10    Cincinnati Bengals           10.0      Cleveland Browns
# 18   1978-09-10        Dallas Cowboys           34.0       New York Giants
# 19   1978-09-10        Houston Oilers           20.0    Kansas City Chiefs
# 20   1978-09-10        Miami Dolphins           42.0       Baltimore Colts
# 21   1978-09-10  New England Patriots           16.0    St Louis Cardinals
# 22   1978-09-10    New Orleans Saints           17.0     Green Bay Packers
# 23   1978-09-10         New York Jets           21.0         Buffalo Bills
# 24   1978-09-10       Oakland Raiders           21.0    San Diego Chargers
# 25   1978-09-10   Philadelphia Eagles           30.0   Washington Redskins
# 26   1978-09-10      Seattle Seahawks           10.0   Pittsburgh Steelers
# 27   1978-09-11        Denver Broncos            9.0     Minnesota Vikings
# 28   1978-09-17         Buffalo Bills           24.0        Miami Dolphins
# 29   1978-09-17         Chicago Bears           19.0         Detroit Lions
# ...         ...                   ...            ...                   ...
# 9168 2016-12-24        Miami Dolphins            NaN         Buffalo Bills
# 9169 2016-12-24     Minnesota Vikings            NaN     Green Bay Packers
# 9170 2016-12-24         New York Jets            NaN  New England Patriots
# 9171 2016-12-24    San Diego Chargers            NaN      Cleveland Browns
# 9172 2016-12-24  Tampa Bay Buccaneers            NaN    New Orleans Saints
# 9173 2016-12-24      Tennessee Titans            NaN  Jacksonville Jaguars
# 9174 2016-12-24   Washington Redskins            NaN         Chicago Bears
# 9175 2016-12-24    Indianapolis Colts            NaN       Oakland Raiders
# 9176 2016-12-24     Arizona Cardinals            NaN      Seattle Seahawks
# 9177 2016-12-24   San Francisco 49ers            NaN      Los Angeles Rams
# 9178 2016-12-24    Cincinnati Bengals            NaN        Houston Texans
# 9179 2016-12-25      Baltimore Ravens            NaN   Pittsburgh Steelers
# 9180 2016-12-25        Denver Broncos            NaN    Kansas City Chiefs
# 9181 2016-12-26         Detroit Lions            NaN        Dallas Cowboys
# 9182 2017-01-01      Baltimore Ravens            NaN    Cincinnati Bengals
# 9183 2017-01-01         Buffalo Bills            NaN         New York Jets
# 9184 2017-01-01     Carolina Panthers            NaN  Tampa Bay Buccaneers
# 9185 2017-01-01         Chicago Bears            NaN     Minnesota Vikings
# 9186 2017-01-01      Cleveland Browns            NaN   Pittsburgh Steelers
# 9187 2017-01-01        Dallas Cowboys            NaN   Philadelphia Eagles
# 9188 2017-01-01     Green Bay Packers            NaN         Detroit Lions
# 9189 2017-01-01        Houston Texans            NaN      Tennessee Titans
# 9190 2017-01-01  Jacksonville Jaguars            NaN    Indianapolis Colts
# 9191 2017-01-01  New England Patriots            NaN        Miami Dolphins
# 9192 2017-01-01    New Orleans Saints            NaN       Atlanta Falcons
# 9193 2017-01-01       New York Giants            NaN   Washington Redskins
# 9194 2017-01-01     Arizona Cardinals            NaN      Los Angeles Rams
# 9195 2017-01-01    Kansas City Chiefs            NaN    San Diego Chargers
# 9196 2017-01-01       Oakland Raiders            NaN        Denver Broncos
# 9197 2017-01-01      Seattle Seahawks            NaN   San Francisco 49ers
#
#       Home Score  Line Total Line  season  week
# 0           13.0   2.0               1978   NaN
# 1            7.0   8.0               1978   NaN
# 2           20.0  -3.5               1978   NaN
# 3           23.0   8.0               1978   NaN
# 4           33.0  -4.0               1978   NaN
# 5           14.0  -4.0               1978   NaN
# 6           17.0 -10.5               1978   NaN
# 7           14.0  -6.0               1978   NaN
# 8           20.0  -6.0               1978   NaN
# 9           24.0   4.5               1978   NaN
# 10          17.0   3.5               1978   NaN
# 11          31.0  -6.5               1978   NaN
# 12          14.0   9.5               1978   NaN
# 13          38.0  10.5               1978   NaN
# 14           7.0  -1.0               1978   NaN
# 15          10.0  10.0               1978   NaN
# 16          13.0  -2.5               1978   NaN
# 17          13.0   5.5               1978   NaN
# 18          24.0 -11.0               1978   NaN
# 19          17.0  -4.5               1978   NaN
# 20           0.0  -3.0               1978   NaN
# 21           6.0  -6.5               1978   NaN
# 22          28.0  -1.5               1978   NaN
# 23          20.0  -5.0               1978   NaN
# 24          20.0  -5.5               1978   NaN
# 25          35.0   3.5               1978   NaN
# 26          21.0  13.5               1978   NaN
# 27          12.0   0.0               1978   NaN
# 28          31.0  12.0               1978   NaN
# 29           0.0  -2.5               1978   NaN
# ...          ...   ...        ...     ...   ...
# 9168         NaN   NaN        NaN    2016   NaN
# 9169         NaN   NaN        NaN    2016   NaN
# 9170         NaN   NaN        NaN    2016   NaN
# 9171         NaN   NaN        NaN    2016   NaN
# 9172         NaN   NaN        NaN    2016   NaN
# 9173         NaN   NaN        NaN    2016   NaN
# 9174         NaN   NaN        NaN    2016   NaN
# 9175         NaN   NaN        NaN    2016   NaN
# 9176         NaN   NaN        NaN    2016   NaN
# 9177         NaN   NaN        NaN    2016   NaN
# 9178         NaN   NaN        NaN    2016   NaN
# 9179         NaN   NaN        NaN    2016   NaN
# 9180         NaN   NaN        NaN    2016   NaN
# 9181         NaN   NaN        NaN    2016   NaN
# 9182         NaN   NaN        NaN    2016   NaN
# 9183         NaN   NaN        NaN    2016   NaN
# 9184         NaN   NaN        NaN    2016   NaN
# 9185         NaN   NaN        NaN    2016   NaN
# 9186         NaN   NaN        NaN    2016   NaN
# 9187         NaN   NaN        NaN    2016   NaN
# 9188         NaN   NaN        NaN    2016   NaN
# 9189         NaN   NaN        NaN    2016   NaN
# 9190         NaN   NaN        NaN    2016   NaN
# 9191         NaN   NaN        NaN    2016   NaN
# 9192         NaN   NaN        NaN    2016   NaN
# 9193         NaN   NaN        NaN    2016   NaN
# 9194         NaN   NaN        NaN    2016   NaN
# 9195         NaN   NaN        NaN    2016   NaN
# 9196         NaN   NaN        NaN    2016   NaN
# 9197         NaN   NaN        NaN    2016   NaN
#
# [9198 rows x 9 columns]

# %%
# find the right week/game and update the score
week_filter = (df_lines.season ==  2016) & (df_lines.week == week)


for ii,rr in df_week.iterrows():
    print ii, rr['home_team'], rr['home_pts']
    game_filter = df_lines[week_filter]['Home Team'].str.contains(rr['home_team'])
    irow = df_lines[week_filter][game_filter].index[0]
    #print df_lines.irow(irow)['Home Team']
    df_lines.loc[irow, 'Home Score'] = rr['home_pts']
    df_lines.loc[irow, 'Visitor Score'] = rr['away_pts']
# Out:
# 17 Buffalo Bills 31
# 18 New England Patriots 31
# 19 Detroit Lions 15
# 20 Cleveland Browns 20
# 21 Houston Texans 19
# 22 Pittsburgh Steelers 24
# 23 Carolina Panthers 46
# 24 Washington Redskins 23
# 25 New York Giants 16
# 26 Arizona Cardinals 40
# 27 Los Angeles Rams 9
# 28 Oakland Raiders 28
# 29 San Diego Chargers 38
# 30 Denver Broncos 34
# 31 Minnesota Vikings 17
# 32 Chicago Bears 14

# %%
df_lines[week_filter]
# Out:
#            Date               Visitor Visitor Score             Home Team  \
# 8958 2016-09-15         New York Jets            37         Buffalo Bills
# 8959 2016-09-18      Baltimore Ravens            25      Cleveland Browns
# 8960 2016-09-18    Cincinnati Bengals            16   Pittsburgh Steelers
# 8961 2016-09-18        Dallas Cowboys            27   Washington Redskins
# 8962 2016-09-18    Kansas City Chiefs            12        Houston Texans
# 8963 2016-09-18        Miami Dolphins            24  New England Patriots
# 8964 2016-09-18    New Orleans Saints            13       New York Giants
# 8965 2016-09-18   San Francisco 49ers            27     Carolina Panthers
# 8966 2016-09-18      Tennessee Titans            16         Detroit Lions
# 8967 2016-09-18      Seattle Seahawks             3      Los Angeles Rams
# 8968 2016-09-18  Tampa Bay Buccaneers             7     Arizona Cardinals
# 8969 2016-09-18       Atlanta Falcons            35       Oakland Raiders
# 8970 2016-09-18    Indianapolis Colts            20        Denver Broncos
# 8971 2016-09-18  Jacksonville Jaguars            14    San Diego Chargers
# 8972 2016-09-18     Green Bay Packers            14     Minnesota Vikings
# 8973 2016-09-19   Philadelphia Eagles            29         Chicago Bears
#
#      Home Score  Line Total Line  season  week
# 8958         31  -1.0        NaN    2016   2.0
# 8959         20  -6.5        NaN    2016   2.0
# 8960         24   3.5        NaN    2016   2.0
# 8961         23   2.5        NaN    2016   2.0
# 8962         19   2.5        NaN    2016   2.0
# 8963         31   6.5        NaN    2016   2.0
# 8964         16   4.5        NaN    2016   2.0
# 8965         46  13.5        NaN    2016   2.0
# 8966         15   6.0        NaN    2016   2.0
# 8967          9  -6.5        NaN    2016   2.0
# 8968         40   6.5        NaN    2016   2.0
# 8969         28   5.0        NaN    2016   2.0
# 8970         34   6.0        NaN    2016   2.0
# 8971         38   3.0        NaN    2016   2.0
# 8972         17  -2.5        NaN    2016   2.0
# 8973         14   3.0        NaN    2016   2.0

# %%
# lines_file2 = lines_file = path_to_lines + "nflAllLines.csv"
df_lines.to_csv(lines_file, index=False)
