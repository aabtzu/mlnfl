# %% [markdown]
# ## nfl lines machine learning project
#
#
# source data for historical spreads and game scores
# http://www.repole.com/sun4cast/data.html

# %%
import os

# define the root directory for the nfl code in $MLNLF_ROOT

#codeDir = "".join([os.environ['MLNFL_ROOT'], os.path.sep])
codeDir = "".join(['/Users/amit/repos/mlnfl/nfl', os.path.sep])
dataRoot = "".join([codeDir, "data", os.path.sep])

os.chdir(codeDir)

print(codeDir)
print(dataRoot)
# Out:
# /Users/amit/repos/mlnfl/nfl/
# /Users/amit/repos/mlnfl/nfl/data/

# %%
# warnings control
import warnings
# choose default, ignore, always
warnings.filterwarnings('default')

# %%
# import necessary modules
# %matplotlib inline

from __future__ import division
from __future__ import print_function
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import madden

from sklearn import linear_model
from sklearn import svm
from sklearn import ensemble

print ("pandas version ",pd.__version__)
# Out:
# /Users/amit/.virtualenvs/datascience/lib/python2.7/site-packages/ipykernel/pylab/config.py:66: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   inline backend."""
# /Users/amit/.virtualenvs/datascience/lib/python2.7/site-packages/ipykernel/pylab/config.py:71: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   'retina', 'jpeg', 'svg', 'pdf'.""")
# /Users/amit/.virtualenvs/datascience/lib/python2.7/site-packages/ipykernel/pylab/config.py:85: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   use `figure_formats` instead)""")
# /Users/amit/.virtualenvs/datascience/lib/python2.7/site-packages/ipykernel/pylab/config.py:95: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """
# /Users/amit/.virtualenvs/datascience/lib/python2.7/site-packages/ipykernel/pylab/config.py:114: DeprecationWarning: metadata {'config': True} was set from the constructor.  Metadata should be set using the .tag() method, e.g., Int().tag(key1='value1', key2='value2')
#   """)
# /Users/amit/.virtualenvs/datascience/lib/python2.7/site-packages/ipykernel/pylab/config.py:44: DeprecationWarning: InlineBackend._config_changed is deprecated: use @observe and @unobserve instead.
#   def _config_changed(self, name, old, new):
# /Users/amit/.virtualenvs/datascience/lib/python2.7/site-packages/traitlets/traitlets.py:770: DeprecationWarning: A parent of InlineBackend._config_changed has adopted the new @observe(change) API
#   clsname, change_or_name), DeprecationWarning)
# pandas version  0.18.0

# %%
# location of lookup files
from referencedata import ReferenceData
lookupFiles = { 'teams' : {'file': 'nflTeams.csv' },
                'seasons' : {'file': 'seasons.csv' },
               }

lookupDir = "".join([dataRoot, 'lookup', os.path.sep])

print ("lookupFiles = %s" % lookupFiles)
print ("lookupDir = %s" % lookupDir)
# Out:
# lookupFiles = {'seasons': {'file': 'seasons.csv'}, 'teams': {'file': 'nflTeams.csv'}}
# lookupDir = /Users/amit/repos/mlnfl/nfl/data/lookup/

# %%
# import reference data
reference_data = ReferenceData(lookupDir)
reference_data.teams_df.head()
# Out:
#                       city      mascot league division  year
# team
# Baltimore Ravens       NaN      Ravens    afc    north   NaN
# New England Patriots   NaN    Patriots    afc     east   NaN
# Tennessee Titans       NaN      Titans    afc    south   NaN
# Atlanta Falcons        NaN     Falcons    nfc    south   NaN
# Tampa Bay Buccaneers   NaN  Buccaneers    nfc    south   NaN

# %%
###  multi-season training
reload(madden)

# testYears and trainYears need to be arrays
trainYears = [2014] #range(2008,2013) 
testYear = [2015]

# train on previous 3 yrs of data
testYear = [2015]
trainYears = range(testYear[0]-3,testYear[0]) 

# training data set - includes one extra year for prev yr record
seasons = np.array(trainYears)
print ("training seasons >> ", seasons)
# Out:
# training seasons >>  [2012 2013 2014]

# %%
reload(madden)

# get training data
# 1 - read all the games
path_to_lines = dataRoot + "lines/"
dfAllGames = madden.readGamesAll(path_to_lines, seasons)
# 2 - compile season record for all teams
dfAllTeams = madden.seasonRecord(dfAllGames, reference_data)
# 3 - apply season records and compute other fields for all games
dfAllGames = madden.processGames(dfAllGames, dfAllTeams, reference_data)
# 4 - remove extra year of data 
dfAllGames = dfAllGames[dfAllGames.season.isin(seasons)]

# use different test set 
seasonTest = np.array(testYear) # should be only one year
print ("results for >> ", seasonTest)
# 1 - read all the games
dfGamesTest = madden.readGamesAll(path_to_lines, seasonTest)  
# 2 - compile season record for all teams
dfTeamsTest = madden.seasonRecord(dfGamesTest,reference_data) 
# 3 - apply season records and compute other fields for all games
dfGamesTest = madden.processGames(dfGamesTest, dfTeamsTest, reference_data) 
# 4 - remove extra year of data 
dfGamesTest = dfGamesTest[dfGamesTest.season.isin(seasonTest)]
# Out:
# madden.py:130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   team_df['gamesPlayed'] = range(1, len(team_df.index) + 1)  # index 1 thur 16
# madden.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   team_df['team'] = team
# madden.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   team_df['homeGame'] = season_df['Home Team'] == team  # true for home game
# madden.py:135: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   (team_df['Visitor Score'] > team_df['Home Score']) & (team_df['homeGame'] == False)
# madden.py:137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   team_df['gamesWon'] = team_df['wonGame'].cumsum()  # cumulative games won
# madden.py:138: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   team_df['homeGamesWon'] = (team_df['wonGame'] & team_df['homeGame']).cumsum()  # cumulative home games won
# madden.py:139: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   team_df['gamesLost'] = team_df['gamesPlayed'] - team_df['gamesWon']  # cumulative games lost
# madden.py:140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   team_df['winPct'] = team_df['gamesWon'] / team_df['gamesPlayed'] # winning pct by week
# madden.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   team_df['homeGamesPlayed'] = team_df['homeGame'].cumsum()  # cumulative home games played
# madden.py:142: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   team_df['homeWinPct'] = team_df['homeGamesWon'] / team_df['homeGamesPlayed'] # home winning pct by week
# /Users/amit/.virtualenvs/datascience/lib/python2.7/site-packages/pandas/core/indexing.py:284: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/amit/.virtualenvs/datascience/lib/python2.7/site-packages/pandas/core/indexing.py:461: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# results for >>  [2015]

# %%
# define independent variables for logistic regression
features = ['favoredRecord','underdogRecord',  # current year records of both teams
            'prevFavoredRecord','prevUnderdogRecord', # prev year records, helps early in season when only few games played
            'gameWeek',  # week in season, should make a good/bad record later in season more important
            'absLine',  # absolute value of spread since favored team already determined
            'divisionGame', # T/F, usually more competitive rivalry games, i.e. bad teams still win home division games.
            'favoredHomeGame', # T/F, important since output of classifier is "did the favored team win?"
            ]

# run the classifer
random_state = 11
#classifier = svm.SVC(kernel='poly',probability=True, random_state=random_state)
classifier = linear_model.LogisticRegression(C=1e5)

mlClassifier = madden.runScikitClassifier(dfAllGames,features,classifier)

# apply results of logistic regression to the test set
dfPredict = madden.predictGames(dfGamesTest,mlClassifier,features)

# apply ranking logic and determine scoring outcomes for league
dfAll = madden.rankGames(dfPredict,reference_data,seasonTest[0])

# %%
dfAllGames
# Out:
#             Date               Visitor  Visitor Score             Home Team  \
# 7918  2012-09-05        Dallas Cowboys           24.0       New York Giants
# 8671  2014-12-28      Cleveland Browns           10.0      Baltimore Ravens
# 8672  2014-12-28         Detroit Lions           20.0     Green Bay Packers
# 8673  2014-12-28  Jacksonville Jaguars           17.0        Houston Texans
# 8674  2014-12-28    San Diego Chargers            7.0    Kansas City Chiefs
# 8675  2014-12-28         New York Jets           37.0        Miami Dolphins
# 8676  2014-12-28         Chicago Bears            9.0     Minnesota Vikings
# 8677  2014-12-28         Buffalo Bills           17.0  New England Patriots
# 8678  2014-12-28   Philadelphia Eagles           34.0       New York Giants
# 8679  2014-12-28    Cincinnati Bengals           17.0   Pittsburgh Steelers
# 8680  2014-12-28    New Orleans Saints           23.0  Tampa Bay Buccaneers
# 8681  2014-12-28    Indianapolis Colts           27.0      Tennessee Titans
# 8682  2014-12-28        Dallas Cowboys           44.0   Washington Redskins
# 8683  2014-12-28      Los Angeles Rams            6.0      Seattle Seahawks
# 8684  2014-12-28       Oakland Raiders           14.0        Denver Broncos
# 8685  2014-12-28     Arizona Cardinals           17.0   San Francisco 49ers
#
#       Home Score  Line Total Line  season  week              favorite  \
# 7918        17.0   4.0         46    2012   NaN       New York Giants
# 7919        41.0  10.0       42.5    2012   NaN         Chicago Bears
# 7920        16.0  -9.5         42    2012   NaN   Philadelphia Eagles
# 7921        48.0   3.0         39    2012   NaN         New York Jets
# 7922        32.0   9.0       50.5    2012   NaN    New Orleans Saints
# 7923        13.0  -6.5         48    2012   NaN  New England Patriots
# 7924        26.0   3.5         38    2012   NaN     Minnesota Vikings
# 7925        30.0  13.5       41.5    2012   NaN        Houston Texans
# 7926        27.0   9.0       46.5    2012   NaN         Detroit Lions
# 7927        24.0  -2.5         43    2012   NaN       Atlanta Falcons
# 7928        22.0   5.5       46.5    2012   NaN     Green Bay Packers
# 7929        16.0  -3.0       45.5    2012   NaN     Carolina Panthers
# 7930        20.0  -3.0         41    2012   NaN      Seattle Seahawks
# 7931        31.0   2.0       45.5    2012   NaN        Denver Broncos
# 7932        44.0   7.0         43    2012   NaN      Baltimore Ravens
# 7933        14.0   1.0       47.5    2012   NaN       Oakland Raiders
# 7934        23.0   5.5         51    2012   NaN     Green Bay Packers
# 7935        41.0   8.0       43.5    2012   NaN       New York Giants
# 7936        18.0  13.5         47    2012   NaN  New England Patriots
# 7937        23.0  -3.0       45.5    2012   NaN     Minnesota Vikings
# 7938        35.0  -3.0         54    2012   NaN    New Orleans Saints
# 7939        35.0   3.0         45    2012   NaN         Buffalo Bills
# 7940        24.0   3.0         47    2012   NaN   Philadelphia Eagles
# 7941        35.0  -2.0         41    2012   NaN       Oakland Raiders
# 7942        34.0   7.0       39.5    2012   NaN    Cincinnati Bengals
# 7943         7.0  -7.0         40    2012   NaN        Houston Texans
# 7944        27.0  -3.0         43    2012   NaN        Dallas Cowboys
# 7945        31.0  -3.5       42.5    2012   NaN   Washington Redskins
# 7946        27.0   4.5         43    2012   NaN   Pittsburgh Steelers
# 7947        38.0   6.0       43.5    2012   NaN    San Diego Chargers
# ...          ...   ...        ...     ...   ...                   ...
# 8656        27.0  -7.5        NaN    2014   NaN   Philadelphia Eagles
# 8657        17.0   3.5        NaN    2014   NaN     Carolina Panthers
# 8658        14.0  -7.0        NaN    2014   NaN         Detroit Lions
# 8659        25.0  -5.0        NaN    2014   NaN      Baltimore Ravens
# 8660        37.0   6.5        NaN    2014   NaN        Miami Dolphins
# 8661        14.0   6.0        NaN    2014   NaN    New Orleans Saints
# 8662        16.0 -10.0        NaN    2014   NaN  New England Patriots
# 8663        20.0   3.0        NaN    2014   NaN   Pittsburgh Steelers
# 8664         3.0 -10.0        NaN    2014   NaN     Green Bay Packers
# 8665        27.0   5.0        NaN    2014   NaN      Los Angeles Rams
# 8666        42.0   3.0        NaN    2014   NaN        Dallas Cowboys
# 8667        26.0  -6.0        NaN    2014   NaN         Buffalo Bills
# 8668         6.0  -8.0        NaN    2014   NaN      Seattle Seahawks
# 8669        37.0  -3.0        NaN    2014   NaN        Denver Broncos
# 8670         3.0   3.0        NaN    2014   NaN       Atlanta Falcons
# 8671        20.0  13.0        NaN    2014   NaN      Baltimore Ravens
# 8672        30.0   7.5        NaN    2014   NaN     Green Bay Packers
# 8673        23.0   9.5        NaN    2014   NaN        Houston Texans
# 8674        19.0   1.0        NaN    2014   NaN    Kansas City Chiefs
# 8675        24.0   6.0        NaN    2014   NaN        Miami Dolphins
# 8676        13.0   6.0        NaN    2014   NaN     Minnesota Vikings
# 8677         9.0   5.0        NaN    2014   NaN  New England Patriots
# 8678        26.0   2.5        NaN    2014   NaN       New York Giants
# 8679        27.0   3.5        NaN    2014   NaN   Pittsburgh Steelers
# 8680        20.0  -4.0        NaN    2014   NaN    New Orleans Saints
# 8681        10.0  -7.0        NaN    2014   NaN    Indianapolis Colts
# 8682        17.0  -5.5        NaN    2014   NaN        Dallas Cowboys
# 8683        20.0  12.0        NaN    2014   NaN      Seattle Seahawks
# 8684        47.0  14.0        NaN    2014   NaN        Denver Broncos
# 8685        20.0   6.0        NaN    2014   NaN   San Francisco 49ers
#
#        ...    homeWin  favoredWin  gameWeek  homeRecord  visitorRecord  \
# 7918   ...          0           0         1    0.000000       0.000000
# 7919   ...          1           1         1    0.000000       0.000000
# 7920   ...          0           1         1    0.000000       0.000000
# 7921   ...          1           1         1    0.000000       0.000000
# 7922   ...          0           0         1    0.000000       0.000000
# 7923   ...          0           1         1    0.000000       0.000000
# 7924   ...          1           1         1    0.000000       0.000000
# 7925   ...          1           1         1    0.000000       0.000000
# 7926   ...          1           1         1    0.000000       0.000000
# 7927   ...          0           1         1    0.000000       0.000000
# 7928   ...          0           0         1    0.000000       0.000000
# 7929   ...          1           0         1    0.000000       0.000000
# 7930   ...          1           0         1    0.000000       0.000000
# 7931   ...          1           1         1    0.000000       0.000000
# 7932   ...          1           1         1    0.000000       0.000000
# 7933   ...          0           0         1    0.000000       0.000000
# 7934   ...          1           1         2    0.000000       1.000000
# 7935   ...          1           1         2    0.000000       1.000000
# 7936   ...          0           0         2    1.000000       1.000000
# 7937   ...          1           0         2    0.000000       1.000000
# 8684     14.0
# 8685      6.0
#
# [768 rows x 23 columns]

# %%
features
# Out:
# ['favoredRecord',
#  'underdogRecord',
#  'prevFavoredRecord',
#  'prevUnderdogRecord',
#  'gameWeek',
#  'absLine',
#  'divisionGame',
#  'favoredHomeGame']

# %%
dfAllGames.to_csv(dataRoot+ 'nfldata_2012_2014.csv', index=False)
dfGamesTest.to_csv(dataRoot+ 'nfldata_2015.csv', index=False)

# %%
# diagnostics ... weekly outcomes
g = dfAll.groupby('gameWeek')['lineScore','probaScore1','probaScore2','probaScore3'].sum()
print(g)

g.sum()
# Out:
#           lineScore  probaScore1  probaScore2  probaScore3
# gameWeek
# 1             104.0        100.0        103.0        100.0
# 2              45.0         62.0         68.0         70.0
# 3             110.0        102.0         94.0         95.0
# 4             105.0        100.0         95.0         94.0
# 5              98.0        104.0         97.0         97.0
# 6              92.0         91.0         94.0         93.0
# 7             100.0        111.0        111.0        111.0
# 8             105.0        106.0        113.0        115.0
# 9              78.0         83.0         82.0         84.0
# 10             34.0         41.0         48.0         51.0
# 11             83.0         84.0         97.0        101.0
# 12             88.0         95.0         91.0         94.0
# 13             95.0        100.0        101.0         99.0
# 14             92.0         96.0        103.0         97.0
# 15            117.0        119.0        119.0        121.0
# 16             76.0         75.0         76.0         77.0
# 17             82.0         84.0         84.0         84.0
# lineScore      1504.0
# probaScore1    1553.0
# probaScore2    1576.0
# probaScore3    1583.0
# dtype: float64

# %%
# predict one week of current season
iweek = 2
reload(madden)

# use different test set - current year
testYear = [2015]
seasonTest = np.array(testYear) # should be only one year
print ("results for >> ", seasonTest)

dfGamesTest = madden.readGamesAll(path_to_lines, seasonTest)
dfTeamsTest = madden.seasonRecord(dfGamesTest,reference_data)
dfGamesTest = madden.processGames(dfGamesTest, dfTeamsTest, reference_data)
dfGamesTest = dfGamesTest[dfGamesTest.season.isin(seasonTest)]

# pick only this weeks games for predict
dfTest = dfGamesTest[dfGamesTest.gameWeek == iweek]

# apply results of logistic regression to the test set
dfPredict = madden.predictGames(dfTest,mlClassifier,features)
# apply ranking logic and determine scoring outcomes for league
dfAll = madden.rankGames(dfPredict, reference_data, seasonTest[0])
# Out:
# results for >>  [2015]

# %%
# display weekly ranking output

# ranking methods choices
# 0. pick based on spread
# 1. always pick favored team, rank by probability of win
# 2. pick winner based on abs(probability - .5), rank by probability
# 3. pick winner based on abs(probability - .5), rank by abs(probability - .5)

dispCols = ['season','gameWeek','Visitor','visitorRecord','Home Team','homeRecord',
            'Line','prevFavoredRecord','prevUnderdogRecord','predict_proba',
            'lineGuess','probaGuess', 'probaAbsGuess', 'predictTeam']


dfAll['predictTeam'] = np.where((dfAll['predict_proba'] - .5) > 0 , dfAll['favorite'], dfAll['underdog'])
guessCol = 'probaGuess'
predictCols = ['gameWeek','predictTeam', 'predict_proba', guessCol, 'favorite','lineGuess', 'Line']
dfAll[predictCols].sort(guessCol, ascending=False)
# Out:
# /Users/amit/.virtualenvs/datascience/lib/python2.7/site-packages/ipykernel/__main__.py:17: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#       gameWeek           predictTeam  predict_proba  probaGuess  \
# 8928        17     Carolina Panthers       0.900338        16.0
# 8686         1  New England Patriots       0.705755        16.0
# 8756         5     Green Bay Packers       0.862176        16.0
# 8745         4     Arizona Cardinals       0.866069        16.0
# 8773         6     Green Bay Packers       0.906347        16.0
# 8786         7  New England Patriots       0.864424        16.0
# 8723         3  New England Patriots       0.925331        16.0
# 8791         8  New England Patriots       0.882147        16.0
# 8807         9  New England Patriots       0.939148        16.0
# 8819        10     Green Bay Packers       0.922728        16.0
# 8858        12     Arizona Cardinals       0.894827        16.0
# 8716         2     Green Bay Packers       0.820589        16.0
# 8870        13    Cincinnati Bengals       0.885612        16.0
# 8887        14    Kansas City Chiefs       0.888508        16.0
# 8843        11      Seattle Seahawks       0.907796        16.0
# 8922        16      Seattle Seahawks       0.914105        16.0
# 8901        15  New England Patriots       0.933182        16.0
# 8748         4      Seattle Seahawks       0.857112        15.0
# 8790         7     Arizona Cardinals       0.829496        15.0
# 8878        14     Arizona Cardinals       0.870123        15.0
# 8724         3     Carolina Panthers       0.890350        15.0
# 8831        10    Cincinnati Bengals       0.889207        15.0
# 8904        15      Seattle Seahawks       0.931753        15.0
# 8914        16    Kansas City Chiefs       0.908897        15.0
# 8845        11  New England Patriots       0.858678        15.0
# 8804         8     Carolina Panthers       0.843438        15.0
# 8713         2        Miami Dolphins       0.810252        15.0
# 8850        12    Cincinnati Bengals       0.847736        15.0
# 8775         6  New England Patriots       0.806727        15.0
# 8875        13  New England Patriots       0.870095        15.0
# ...        ...                   ...            ...         ...
# 8916        16    New Orleans Saints       0.545752         3.0
# 8837        11        Denver Broncos       0.404528         3.0
# 8871        13      Tennessee Titans       0.511483         3.0
# 8779         7   Washington Redskins       0.518233         3.0
# 8728         3      Los Angeles Rams       0.411354         3.0
# 8907        15        Miami Dolphins       0.460283         3.0
# 8846        12   Philadelphia Eagles       0.479035         3.0
# 8799         8    Cincinnati Bengals       0.421923         3.0
# 8823        10   Washington Redskins       0.386719         3.0
# 8880        14   San Francisco 49ers       0.453132         3.0
# 8717         2         New York Jets       0.442363         3.0
# 8867        13      Seattle Seahawks       0.495121         2.0
# 8855        12      Tennessee Titans       0.469583         2.0
# 8720         3      Tennessee Titans       0.394366         2.0
# 8704         2   San Francisco 49ers       0.409217         2.0
# 8919        16  Tampa Bay Buccaneers       0.520343         2.0
# 8937        17         Chicago Bears       0.524298         2.0
# 8881        14      Los Angeles Rams       0.438582         2.0
# 8734         4   Pittsburgh Steelers       0.382373         2.0
# 8894        15  Tampa Bay Buccaneers       0.439716         2.0
# 8688         1    Kansas City Chiefs       0.443580         2.0
# 8915        16    Indianapolis Colts       0.472009         1.0
# 8863        13       New York Giants       0.487605         1.0
# 8935        17        Dallas Cowboys       0.518780         1.0
# 8893        14        Miami Dolphins       0.431878         1.0
# 8692         1  Jacksonville Jaguars       0.429818         1.0
# 8711         2       Atlanta Falcons       0.259838         1.0
# 8851        12     Minnesota Vikings       0.469198         1.0
# 8902        15   Washington Redskins       0.370711         1.0
# 8722         3    Cincinnati Bengals       0.355384         1.0
#
#                   favorite  lineGuess  Line
# 8928     Carolina Panthers       16.0  10.5
# 8686  New England Patriots       16.0   7.0
# 8756     Green Bay Packers       15.0   9.0
# 8745     Arizona Cardinals       12.0   7.0
# 8773     Green Bay Packers       16.0  10.5
# 8786  New England Patriots       16.0   9.0
# 8723  New England Patriots       15.0  13.5
# 8791  New England Patriots       15.0   8.0
# 8807  New England Patriots       16.0  14.0
# 8819     Green Bay Packers       16.0  11.5
# 8858     Arizona Cardinals       16.0 -10.5
# 8716     Green Bay Packers       10.0   3.5
# 8870    Cincinnati Bengals       15.0  -9.5
# 8887    Kansas City Chiefs       15.0  10.0
# 8843      Seattle Seahawks       16.0  12.5
# 8922      Seattle Seahawks       16.0  13.5
# 8901  New England Patriots       15.0  14.0
# 8748      Seattle Seahawks       16.0  10.0
# 8790     Arizona Cardinals       15.0   7.5
# 8878     Arizona Cardinals       16.0  11.0
# 8724     Carolina Panthers       14.0   6.5
# 8831    Cincinnati Bengals       15.0  10.5
# 8904      Seattle Seahawks       16.0  14.5
# 8914    Kansas City Chiefs       15.0  12.5
# 8845  New England Patriots       15.0   7.0
# 8804     Carolina Panthers       13.0   7.0
# 8713        Miami Dolphins       14.0  -6.0
# 8850    Cincinnati Bengals       14.0   9.0
# 8775  New England Patriots       15.0  -7.5
# 8875  New England Patriots       16.0   9.5
# ...                    ...        ...   ...
# 8916    New Orleans Saints        5.0   3.5
# 8837         Chicago Bears        4.0   1.0
# 8871      Tennessee Titans        4.0   2.5
# 8779   Washington Redskins        6.0   3.5
# 8728   Pittsburgh Steelers        1.0  -1.0
# 8907    San Diego Chargers        3.0   1.5
# 8846         Detroit Lions        2.0   1.0
# 8799   Pittsburgh Steelers        3.0   0.1
# 8823    New Orleans Saints        3.0  -1.0
# 8880      Cleveland Browns        4.0   1.5
# 8717    Indianapolis Colts       15.0   7.0
# 8867     Minnesota Vikings        1.0   0.1
# 8855       Oakland Raiders        3.0  -2.0
# 8720    Indianapolis Colts        8.0  -3.5
# 8704   Pittsburgh Steelers       12.0   5.5
# 8919  Tampa Bay Buccaneers        3.0   3.0
# 8937         Chicago Bears        1.0   1.0
# 8881         Detroit Lions        5.0  -2.5
# 8734      Baltimore Ravens        3.0  -2.5
# 8894      Los Angeles Rams        4.0   1.5
# 8688        Houston Texans        1.0   1.0
# 8915        Miami Dolphins        1.0   1.5
# 8863         New York Jets        2.0  -2.0
# 8935        Dallas Cowboys        5.0   3.5
# 8893       New York Giants        1.0  -1.0
# 8692     Carolina Panthers        6.0  -3.0
# 8711       New York Giants        4.0   2.0
# 8851       Atlanta Falcons        4.0   2.0
# 8902         Buffalo Bills        2.0  -1.0
# 8722      Baltimore Ravens        5.0   2.5
#
# [256 rows x 7 columns]

# %%
dfAll[predictCols].to_csv(dataRoot + 'predict2015.csv', index=False)

# %%
week_filter = dfAll.gameWeek >=1

dfAll['predictTeam'] = np.where((dfAll['predict_proba'] - .5) > 0 , dfAll['favorite'], dfAll['underdog'])
dfAll[week_filter][predictCols].sort(guessCol, ascending=False)
# Out:
# /Users/amit/.virtualenvs/datascience/lib/python2.7/site-packages/ipykernel/__main__.py:4: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# KeyErrorTraceback (most recent call last)
# <ipython-input-42-944df2edf8e3> in <module>()
#       2
#       3 dfAll['predictTeam'] = np.where((dfAll['predict_proba'] - .5) > 0 , dfAll['favorite'], dfAll['underdog'])
# ----> 4 dfAll[week_filter][predictCols].sort(guessCol, ascending=False)
#
# /Users/amit/.virtualenvs/datascience/lib/python2.7/site-packages/pandas/core/frame.pyc in sort(self, columns, axis, ascending, inplace, kind, na_position)
#    3216         return self.sort_values(by=columns, axis=axis, ascending=ascending,
#    3217                                 inplace=inplace, kind=kind,
# -> 3218                                 na_position=na_position)
#    3219
#    3220     @Appender(_shared_docs['sort_index'] % _shared_doc_kwargs)
#
# /Users/amit/.virtualenvs/datascience/lib/python2.7/site-packages/pandas/core/frame.pyc in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    3143
#    3144             by = by[0]
# -> 3145             k = self[by].values
#    3146             if k.ndim == 2:
#    3147
#
# /Users/amit/.virtualenvs/datascience/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1990             return self._getitem_multilevel(key)
#    1991         else:
# -> 1992             return self._getitem_column(key)
#    1993
#    1994     def _getitem_column(self, key):
#
# /Users/amit/.virtualenvs/datascience/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1997         # get column
#    1998         if self.columns.is_unique:
# -> 1999             return self._get_item_cache(key)
#    2000
#    2001         # duplicate columns & possible reduce dimensionality
#
# /Users/amit/.virtualenvs/datascience/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1343         res = cache.get(item)
#    1344         if res is None:
# -> 1345             values = self._data.get(item)
#    1346             res = self._box_item_values(item, values)
#    1347             cache[item] = res
#
# /Users/amit/.virtualenvs/datascience/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3223
#    3224             if not isnull(item):
# -> 3225                 loc = self.items.get_loc(item)
#    3226             else:
#    3227                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/amit/.virtualenvs/datascience/lib/python2.7/site-packages/pandas/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    1876                 return self._engine.get_loc(key)
#    1877             except KeyError:
# -> 1878                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1879
#    1880         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4027)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3891)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12408)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12359)()
#
# KeyError: 'probaGuess'

# %%
# display weekly ranking output for spread method

# ranking methods choices
# 0. pick based on spread
# 1. always pick favored team, rank by probability of win
# 2. pick winner based on abs(probability - .5), rank by probability
# 3. pick winner based on abs(probability - .5), rank by abs(probability - .5)

predictCols = ['favorite','lineGuess', 'absLine','Line', 'favoredHomeGame', 'divisionGame', 'favoredRecord', 'gameWeek']

sortCols = ['gameWeek', 'absLine','favoredHomeGame', 'divisionGame', 'favoredRecord', 'favorite']
dfSpread = dfAll[predictCols].sort(sortCols , ascending=True)
#print(dfSpread.to_csv(sys.stdout,sep=',', index=False))
dfSpread
# Out:
# /Users/amit/.virtualenvs/datascience/lib/python2.7/site-packages/ipykernel/__main__.py:12: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#                   favorite  lineGuess  absLine  Line  favoredHomeGame  \
# 8688        Houston Texans        1.0      1.0   1.0                1
# 8690    Indianapolis Colts        2.0      2.5  -2.5                0
# 8701     Minnesota Vikings        3.0      2.5  -2.5                0
# 8694     Arizona Cardinals        4.0      2.5   2.5                1
# 8692     Carolina Panthers        6.0      3.0  -3.0                0
# 8700   Philadelphia Eagles        5.0      3.0  -3.0                0
# 8689         New York Jets        7.0      3.0   3.0                1
# 8695    San Diego Chargers        8.0      3.0   3.0                1
# 8696  Tampa Bay Buccaneers        9.0      3.0   3.0                1
# 8697    Cincinnati Bengals       10.0      3.5  -3.5                0
# 8691        Miami Dolphins       11.0      3.5  -3.5                0
# 8693      Seattle Seahawks       12.0      4.0  -4.0                0
# 8698        Denver Broncos       13.0      4.5   4.5                1
# 8699        Dallas Cowboys       14.0      6.0   6.0                1
# 8687     Green Bay Packers       15.0      6.5  -6.5                0
# 8686  New England Patriots       16.0      7.0   7.0                1
# 8710      Tennessee Titans        1.0      1.0  -1.0                0
# 8708  New England Patriots        2.0      1.0  -1.0                0
# 8707     Arizona Cardinals        3.0      1.5  -1.5                0
# 8711       New York Giants        4.0      2.0   2.0                1
# 8703     Carolina Panthers        5.0      3.0   3.0                1
# 8709    Cincinnati Bengals        6.0      3.0   3.0                1
# 8706     Minnesota Vikings        7.0      3.0   3.0                1
# 8702    Kansas City Chiefs        8.0      3.0   3.0                1
# 8712      Los Angeles Rams        9.0      3.5  -3.5                0
# 8716     Green Bay Packers       10.0      3.5   3.5                1
# 8715   Philadelphia Eagles       11.0      5.0   5.0                1
# 8704   Pittsburgh Steelers       12.0      5.5   5.5                1
# 8714      Baltimore Ravens       13.0      6.0  -6.0                0
# 8713        Miami Dolphins       14.0      6.0  -6.0                0
# ...                    ...        ...      ...   ...              ...
# 8919  Tampa Bay Buccaneers        3.0      3.0   3.0                1
# 8911   Philadelphia Eagles        4.0      3.0   3.0                1
# 8916    New Orleans Saints        5.0      3.5   3.5                1
# 8925        Denver Broncos        6.0      3.5   3.5                1
# 8923     Arizona Cardinals        7.0      4.5   4.5                1
# 8913      Tennessee Titans        8.0      4.5   4.5                1
# 8910       Oakland Raiders        9.0      5.5   5.5                1
# 8918         Buffalo Bills       10.0      6.0   6.0                1
# 8921     Minnesota Vikings       11.0      6.0   6.0                1
# 8920     Carolina Panthers       12.0      7.0  -7.0                0
# 8917         Detroit Lions       13.0      9.0   9.0                1
# 8924   Pittsburgh Steelers       14.0     10.0 -10.0                0
# 8914    Kansas City Chiefs       15.0     12.5  12.5                1
# 8922      Seattle Seahawks       16.0     13.5  13.5                1
# 8937         Chicago Bears        1.0      1.0   1.0                1
# 8926         New York Jets        2.0      3.0  -3.0                0
# 8938     Green Bay Packers        3.0      3.0   3.0                1
# 8941      Los Angeles Rams        4.0      3.5  -3.5                0
# 8935        Dallas Cowboys        5.0      3.5   3.5                1
# 8936       New York Giants        6.0      3.5   3.5                1
# 8929       Atlanta Falcons        7.0      4.0   4.0                1
# 8933    Indianapolis Colts        8.0      6.0   6.0                1
# 8932        Houston Texans        9.0      6.0   6.0                1
# 8934    Kansas City Chiefs       10.0      6.5   6.5                1
# 8940     Arizona Cardinals       11.0      6.5   6.5                1
# 8930    Cincinnati Bengals       12.0      9.0   9.0                1
# 8939        Denver Broncos       13.0      9.0   9.0                1
# 8931   Pittsburgh Steelers       14.0     10.5 -10.5                0
# 8927  New England Patriots       15.0     10.5 -10.5                0
# 8928     Carolina Panthers       16.0     10.5  10.5                1
#
#       divisionGame  favoredRecord  gameWeek
# 8688             0       0.000000         1
# 8690             0       0.000000         1
# 8701             0       0.000000         1
# 8694             0       0.000000         1
# 8692             0       0.000000         1
# 8700             0       0.000000         1
# 8689             0       0.000000         1
# 8695             0       0.000000         1
# 8696             0       0.000000         1
# 8697             0       0.000000         1
# 8691             0       0.000000         1
# 8693             1       0.000000         1
# 8698             0       0.000000         1
# 8699             1       0.000000         1
# 8687             1       0.000000         1
# 8686             0       0.000000         1
# 8710             0       1.000000         2
# 8708             1       1.000000         2
# 8707             0       1.000000         2
# 8711             0       0.000000         2
# 8703             0       1.000000         2
# 8709             0       1.000000         2
# 8706             1       0.000000         2
# 8702             1       1.000000         2
# 8712             0       1.000000         2
# 8716             0       1.000000         2
# 8715             1       0.000000         2
# 8704             0       0.000000         2
# 8714             0       0.000000         2
# 8713             0       1.000000         2
# ...            ...            ...       ...
# 8919             0       0.400000        16
# 8911             1       0.400000        16
# 8916             0       0.400000        16
# 8925             0       0.733333        16
# 8923             0       0.866667        16
# 8913             1       0.200000        16
# 8910             1       0.466667        16
# 8918             0       0.466667        16
# 8921             0       0.666667        16
# 8920             1       0.933333        16
# 8917             0       0.400000        16
# 8924             1       0.600000        16
# 8914             0       0.666667        16
# 8922             1       0.600000        16
# 8937             1       0.375000        17
# 8926             1       0.625000        17
# 8938             1       0.625000        17
# 8941             1       0.437500        17
# 8935             1       0.250000        17
# 8936             1       0.375000        17
# 8929             1       0.500000        17
# 8933             1       0.500000        17
# 8932             1       0.562500        17
# 8934             1       0.687500        17
# 8940             1       0.812500        17
# 8930             1       0.750000        17
# 8939             1       0.750000        17
# 8931             1       0.625000        17
# 8927             1       0.750000        17
# 8928             1       0.937500        17
#
# [256 rows x 8 columns]

# %%
dfSpread.to_csv(dataRoot + 'predict2015.csv', index=False)

# %%
# loop over multiple years

import runMadden
import walsh
reload(madden)
reload(runMadden)


trainStart = 2010
trainLen = 3

random_state = None
mlClassifier = svm.SVC(kernel='poly',probability=True, random_state=random_state)
dfSVM = runMadden.runSeasonLoop(trainStart, trainLen, mlClassifier, path_to_lines, reference_data)

mlClassifier = linear_model.LogisticRegression(C=1e5)
dfLog = runMadden.runSeasonLoop(trainStart, trainLen, mlClassifier, path_to_lines, reference_data)
#dfLoop = dfSVM
# Out:
# 2013 [2010, 2011, 2012]
# 1653 <type 'int'>
# 2014 [2011, 2012, 2013]
# 1664 <type 'int'>
# 2013 [2010, 2011, 2012]
# 1653 <type 'int'>
# 2014 [2011, 2012, 2013]
# 1664 <type 'int'>

# %%
dfSVM
# Out:
#         lineScore  probaScore1  probaScore2  probaScore3        trainYears  \
# season
# 2013            2            8            2          -17  [2010 2011 2012]
# 2014            5           85           99          113  [2011 2012 2013]
#
#                            classifierType  \
# season
# 2013    <class 'sklearn.svm.classes.SVC'>
# 2014    <class 'sklearn.svm.classes.SVC'>
#
#                                                classifier
# season
# 2013    SVC(C=1.0, cache_size=200, class_weight=None, ...
# 2014    SVC(C=1.0, cache_size=200, class_weight=None, ...

# %%
dfLog
# Out:
#         lineScore  probaScore1  probaScore2  probaScore3        trainYears  \
# season
# 2013            2           28           40           35  [2010 2011 2012]
# 2014            5            5          -35          -47  [2011 2012 2013]
#
#                                            classifierType  \
# season
# 2013    <class 'sklearn.linear_model.logistic.Logistic...
# 2014    <class 'sklearn.linear_model.logistic.Logistic...
#
#                                                classifier
# season
# 2013    LogisticRegression(C=100000.0, class_weight=No...
# 2014    LogisticRegression(C=100000.0, class_weight=No...
