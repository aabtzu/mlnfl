# %% [markdown]
# ## nfl lines machine learning project
#
#
# source data for historical spreads and game scores
# http://www.repole.com/sun4cast/data.html

# %%
import os

# define the root directory for the nfl code in $MLNLF_ROOT
codeDir = "".join([os.environ['MLNFL_ROOT'], os.path.sep])
dataRoot = "".join([codeDir, "data", os.path.sep])

os.chdir(codeDir)

print(codeDir)
print(dataRoot)
# Out:
# /Users/amit.bhattacharyya/repos/mlnfl/nfl/
# /Users/amit.bhattacharyya/repos/mlnfl/nfl/data/

# %%
# warnings control
import warnings
# choose default, ignore, always
warnings.filterwarnings('default')

# %%
# import necessary modules
# %matplotlib inline

from __future__ import division
from __future__ import print_function
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cProfile


import madden

#import sklearn_pandas
from sklearn import linear_model
from sklearn import svm
from sklearn import ensemble

print ("pandas version ",pd.__version__)
# Out:
# pandas version  0.15.1

# %%
# location of lookup files
from referencedata import ReferenceData
lookupFiles = { 'teams' : {'file': 'nflTeams.csv' },
                'seasons' : {'file': 'seasons.csv' },
               }

lookupDir = "".join([dataRoot, 'lookup', os.path.sep])

print ("lookupFiles = %s" % lookupFiles)
print ("lookupDir = %s" % lookupDir)
# Out:
# lookupFiles = {'seasons': {'file': 'seasons.csv'}, 'teams': {'file': 'nflTeams.csv'}}
# lookupDir = /Users/amit.bhattacharyya/repos/mlnfl/nfl/data/lookup/

# %%
# import reference data
reference_data = ReferenceData(lookupDir)
reference_data.teams_df
# Out:
#                       city  mascot league division  year
# team
# Baltimore Ravens       NaN     NaN    afc    north   NaN
# New England Patriots   NaN     NaN    afc     east   NaN
# Tennessee Titans       NaN     NaN    afc    south   NaN
# Atlanta Falcons        NaN     NaN    nfc    south   NaN
# Tampa Bay Buccaneers   NaN     NaN    nfc    south   NaN
# Kansas City Chiefs     NaN     NaN    afc     west   NaN
# Cincinnati Bengals     NaN     NaN    afc    north   NaN
# Miami Dolphins         NaN     NaN    afc     east   NaN
# Seattle Seahawks       NaN     NaN    nfc     west   NaN
# Minnesota Vikings      NaN     NaN    nfc    north   NaN
# Oakland Raiders        NaN     NaN    afc     west   NaN
# Arizona Cardinals      NaN     NaN    nfc     west   NaN
# Green Bay Packers      NaN     NaN    nfc    north   NaN
# New York Giants        NaN     NaN    nfc     east   NaN
# Philadelphia Eagles    NaN     NaN    nfc     east   NaN
# Houston Texans         NaN     NaN    afc    south   NaN
# New York Jets          NaN     NaN    afc     east   NaN
# San Diego Chargers     NaN     NaN    afc     west   NaN
# Cleveland Browns       NaN     NaN    afc    north   NaN
# Carolina Panthers      NaN     NaN    nfc    south   NaN
# St Louis Rams          NaN     NaN    nfc     west   NaN
# Washington Redskins    NaN     NaN    nfc     east   NaN
# Dallas Cowboys         NaN     NaN    nfc     east   NaN
# New Orleans Saints     NaN     NaN    nfc    south   NaN
# Detroit Lions          NaN     NaN    nfc    north   NaN
# Jacksonville Jaguars   NaN     NaN    afc    south   NaN
# Denver Broncos         NaN     NaN    afc     west   NaN
# San Francisco 49ers    NaN     NaN    nfc     west   NaN
# Pittsburgh Steelers    NaN     NaN    afc    north   NaN
# Indianapolis Colts     NaN     NaN    afc    south   NaN
# Buffalo Bills          NaN     NaN    afc     east   NaN
# Chicago Bears          NaN     NaN    nfc    north   NaN

# %%
###  multi-season training
reload(madden)

# testYears and trainYears need to be arrays
trainYears = [2013] #range(2008,2013) 
testYear = [2014]

# train on previous 3 yrs of data
#testYear = [2014]
#trainYears = range(testYear[0]-3,testYear[0]) 

# training data set - includes one extra year for prev yr record
seasons = np.array(trainYears)
print ("training seasons >> ", seasons)
# Out:
# training seasons >>  [2013]

# %%
reload(madden)

# get training data
# 1 - read all the games
path_to_lines = dataRoot + "lines/"
dfAllGames = madden.readGamesAll(path_to_lines, seasons)
# 2 - compile season record for all teams
dfAllTeams = madden.seasonRecord(dfAllGames, reference_data)
# 3 - apply season records and compute other fields for all games
dfAllGames = madden.processGames(dfAllGames, dfAllTeams, reference_data)
# 4 - remove extra year of data 
dfAllGames = dfAllGames[dfAllGames.season.isin(seasons)]

# use different test set 
seasonTest = np.array(testYear) # should be only one year
print ("results for >> ", seasonTest)
# 1 - read all the games
dfGamesTest = madden.readGamesAll(path_to_lines, seasonTest)  
# 2 - compile season record for all teams
dfTeamsTest = madden.seasonRecord(dfGamesTest,reference_data) 
# 3 - apply season records and compute other fields for all games
dfGamesTest = madden.processGames(dfGamesTest, dfTeamsTest, reference_data) 
# 4 - remove extra year of data 
dfGamesTest = dfGamesTest[dfGamesTest.season.isin(seasonTest)]
# Out:
# results for >>  [2014]

# %%
reload(madden)

# define independent variables for logistic regression
features = ['favoredRecord','underdogRecord',  # current year records of both teams
            'prevFavoredRecord','prevUnderdogRecord', # prev year records, helps early in season when only few games played
            'gameWeek',  # week in season, should make a good/bad record later in season more important
            'absLine',  # absolute value of spread since favored team already determined
            'divisionGame', # T/F, usually more competitive rivalry games, i.e. bad teams still win home division games.
            'favoredHomeGame', # T/F, important since output of classifier is "did the favored team win?"
            ]

# run the classifer
#classifier = svm.SVC(kernel='poly',probability=True)
classifier = linear_model.LogisticRegression(C=1e5)
#classifier = ensemble.RandomForestClassifier(n_estimators=10)
mlClassifier = madden.runScikitClassifier(dfAllGames,features,classifier)

# apply results of logistic regression to the test set
dfPredict = madden.predictGames(dfGamesTest,mlClassifier,features)

# apply ranking logic and determine scoring outcomes for league
dfAll = madden.rankGames(dfPredict,reference_data,seasonTest[0])
# Out:
# training data accuracy =  0.70703125
#              score  win by   win
# lineScore     1044    1044  True
# probaScore1   1056    1056  True
# probaScore2   1036    1036  True
# probaScore3   1025    1025  True

# %%
reload(madden)
# define and run the classifer
classifier = linear_model.LogisticRegression(C=1e5)

classifier = svm.SVC(probability=True)
mlClassifier = madden.runScikitClassifier(dfAllGames,features,classifier)
dfPredict = madden.predictGames(dfGamesTest,mlClassifier,features)
# apply ranking logic and determine scoring outcomes for league
dfAll = madden.rankGames(dfPredict,reference_data,seasonTest[0])
# Out:
# training data accuracy =  0.71875
#              score  win by   win
# lineScore     1044    1044  True
# probaScore1   1025    1025  True
# probaScore2   1025    1025  True
# probaScore3   1025    1025  True

# %%
# diagnostics ... weekly outcomes
g = dfAll.groupby('gameWeek')['lineScore','probaScore1','probaScore2','probaScore3'].sum()
print(g)

g.sum()
# Out:
#           lineScore  probaScore1  probaScore2  probaScore3
# gameWeek
# 1                94           81           81           81
# 2                79           76           76           76
# 3                97           94           94           94
# 4                81           82           82           82
# 5               117          117          117          117
# 6                99          104          104          104
# 7               105           99           99           99
# 8                98          105          105          105
# 9                95           94           94           94
# 10              105           94           94           94
# 11               74           79           79           79
# 12              NaN          NaN            0            0
# lineScore      1044
# probaScore1    1025
# probaScore2    1025
# probaScore3    1025
# dtype: float64

# %%
# predict one week of current season
iweek = 12
reload(madden)

# use different test set - current year
testYear = [2014]
seasonTest = np.array(testYear) # should be only one year
print ("results for >> ", seasonTest)

dfGamesTest = madden.readGamesAll(path_to_lines, seasonTest)
dfTeamsTest = madden.seasonRecord(dfGamesTest,reference_data)
dfGamesTest = madden.processGames(dfGamesTest, dfTeamsTest, reference_data)
dfGamesTest = dfGamesTest[dfGamesTest.season.isin(seasonTest)]

# pick only this weeks games for predict
dfTest = dfGamesTest[dfGamesTest.gameWeek == iweek]

# apply results of logistic regression to the test set
dfPredict = madden.predictGames(dfTest,mlClassifier,features)
# apply ranking logic and determine scoring outcomes for league
dfAll = madden.rankGames(dfPredict,reference_data,seasonTest[0])
# Out:
# results for >>  [2014]
#              score  win by    win
# lineScore      NaN     NaN  False
# probaScore1    NaN     NaN  False
# probaScore2      0       0  False
# probaScore3      0       0  False
# madden.py:392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   dfPredict['predict_proba'] = pp[:, 1]
# madden.py:393: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   dfPredict['predict_proba_abs'] = abs(pp[:, 1] - 0.5)

# %%
# display weekly ranking output

# ranking methods choices
# 0. pick based on spread
# 1. always pick favored team, rank by probability of win
# 2. pick winner based on abs(probability - .5), rank by probability
# 3. pick winner based on abs(probability - .5), rank by abs(probability - .5)

dispCols = ['season','gameWeek','Visitor','visitorRecord','Home Team','homeRecord',
            'Line','prevFavoredRecord','prevUnderdogRecord','predict_proba',
            'lineGuess','probaGuess', 'probaAbsGuess', 'predictTeam']


dfAll['predictTeam'] = np.where((dfAll['predict_proba'] - .5) > 0 , dfAll['favorite'], dfAll['underdog'])
guessCol = 'probaGuess'
predictCols = ['predictTeam', 'predict_proba', guessCol, 'favorite','lineGuess', 'Line']
dfAll[predictCols].sort(guessCol, ascending=False)
# Out:
#                predictTeam  predict_proba  probaGuess              favorite  \
# 8591    Kansas City Chiefs       0.697999          16    Kansas City Chiefs
# 8598  New England Patriots       0.696957          15  New England Patriots
# 8602        Denver Broncos       0.695993          14        Denver Broncos
# 8601      Seattle Seahawks       0.695670          13      Seattle Seahawks
# 8605    New Orleans Saints       0.693075          12    New Orleans Saints
# 8595        Houston Texans       0.692371          11        Houston Texans
# 8596    Indianapolis Colts       0.691186          10    Indianapolis Colts
# 8592       Atlanta Falcons       0.689425           9       Atlanta Falcons
# 8600    San Diego Chargers       0.688822           8    San Diego Chargers
# 8594         Chicago Bears       0.685114           7         Chicago Bears
# 8593         Buffalo Bills       0.683717           6         Buffalo Bills
# 8604        Dallas Cowboys       0.682282           5        Dallas Cowboys
# 8603   San Francisco 49ers       0.679793           4   San Francisco 49ers
# 8597     Green Bay Packers       0.653456           3     Green Bay Packers
# 8599   Philadelphia Eagles       0.640144           2   Philadelphia Eagles
#
#       lineGuess  Line
# 8591         10  -7.0
# 8598         12   7.0
# 8602         11   7.0
# 8601          9   6.5
# 8605          5   3.5
# 8595          2   2.0
# 8596         16  14.0
# 8592          4   3.0
# 8600          7   5.0
# 8594          8   5.5
# 8593          6   4.5
# 8604          3  -3.0
# 8603         13   8.5
# 8597         14  -9.5
# 8599         15  11.0

# %%
# display weekly ranking output for spread method

# ranking methods choices
# 0. pick based on spread
# 1. always pick favored team, rank by probability of win
# 2. pick winner based on abs(probability - .5), rank by probability
# 3. pick winner based on abs(probability - .5), rank by abs(probability - .5)

predictCols = ['favorite','lineGuess', 'absLine','Line', 'favoredHomeGame', 'divisionGame', 'favoredRecord']

sortCols = ['absLine','favoredHomeGame', 'divisionGame', 'favoredRecord', 'favorite']
dfSpread = dfAll[predictCols].sort(sortCols , ascending=False)
#print(dfSpread.to_csv(sys.stdout,sep=',', index=False))
dfSpread
# Out:
#                   favorite  lineGuess  absLine  Line  favoredHomeGame  \
# 8596    Indianapolis Colts         16     14.0  14.0                1
# 8599   Philadelphia Eagles         15     11.0  11.0                1
# 8597     Green Bay Packers         14      9.5  -9.5                0
# 8603   San Francisco 49ers         13      8.5   8.5                1
# 8598  New England Patriots         12      7.0   7.0                1
# 8602        Denver Broncos         11      7.0   7.0                1
# 8591    Kansas City Chiefs         10      7.0  -7.0                0
# 8601      Seattle Seahawks          9      6.5   6.5                1
# 8594         Chicago Bears          8      5.5   5.5                1
# 8600    San Diego Chargers          7      5.0   5.0                1
# 8593         Buffalo Bills          6      4.5   4.5                1
# 8605    New Orleans Saints          5      3.5   3.5                1
# 8592       Atlanta Falcons          4      3.0   3.0                1
# 8604        Dallas Cowboys          3      3.0  -3.0                0
# 8595        Houston Texans          2      2.0   2.0                1
#
#       divisionGame  favoredRecord
# 8596             1       0.545455
# 8599             0       0.636364
# 8597             1       0.636364
# 8603             0       0.545455
# 8598             0       0.727273
# 8602             0       0.636364
# 8591             1       0.636364
# 8601             1       0.545455
# 8594             0       0.363636
# 8600             0       0.545455
# 8593             1       0.454545
# 8605             0       0.363636
# 8592             0       0.363636
# 8604             1       0.636364
# 8595             0       0.454545

# %%
# display details for a single week
dispWeek = 7
dispCols = ['season','gameWeek','Visitor','Home Team',
            'visitorRecord', 'homeRecord', 'favoredRecord','underdogRecord',
            'prevFavoredRecord','Line','predict_proba','Visitor Score',
            'Home Score','favoredWin','predictWin','lineGuess','probaGuess', 'lineScore','probaScore1','probaScore2']

print(dfAll[dfAll.gameWeek == dispWeek]['lineScore'].sum())
dfAll[dfAll.gameWeek == dispWeek][dispCols]
# Out:
# 0
# Empty DataFrame
# Columns: [season, gameWeek, Visitor, Home Team, visitorRecord, homeRecord, favoredRecord, underdogRecord, prevFavoredRecord, Line, predict_proba, Visitor Score, Home Score, favoredWin, predictWin, lineGuess, probaGuess, lineScore, probaScore1, probaScore2]
# Index: []

# %%
# diagnostics ... plot outcomes of games
nWin = dfAllGames.favoredWin.index.tolist()
nLose = dfAllGames[dfAllGames['favoredWin'] == 0].index.tolist()

plt.plot(dfAllGames.favoredRecord[nWin],dfAllGames.underdogRecord[nWin],'bx')
plt.plot(dfAllGames.favoredRecord[nLose],dfAllGames.underdogRecord[nLose],'rx')

# %%
# diagnostics ... logreg variables

# print classifiers
print("classifiers > ",logreg.classes_)

# coefficients
cc = logreg.coef_
cc.shape
print("coeffs")
for ii,ff in enumerate(features):
    print(ii,ff,cc[0][ii])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-159-e58d7170a0e2> in <module>()
#       2
#       3 # print classifiers
# ----> 4 print("classifiers > ",logreg.classes_)
#       5
#       6 # coefficients
#
# NameError: name 'logreg' is not defined

# %%
# run one year of rolling training, control width of training window w/ trainFreq
import runMadden
reload(runMadden)
reload(madden)

# need to be arrays
trainYears = [2012] #range(2008.2013) 
testYear = [2013]
trainFreq = 6

dd = runMadden.runSeasonRolling(trainYears,testYear,olookups,trainFreq)
dd

# %%
# loop over years to test trainFreq

reload(runMadden)
reload(madden)

ddd = None
for y in range(2008,2013):
    trainYears = [y]
    testYear = [y+1]
    trainFreq = 20
    dd = runMadden.runSeasonRolling(trainYears,testYear,olookups,trainFreq)
    if ddd is None:
        ddd = dd
    else:
        ddd = ddd.append(dd)
        
ddd

# %%
# diagnostics ... plot outcomes of games
nWin = dfAll.favoredWin.index.tolist()
nLose = dfAll[dfAll['favoredWin'] == 0].index.tolist()

plt.plot(dfAll.favoredRecord[nWin],dfAll.underdogRecord[nWin],'bx')
plt.plot(dfAll.favoredRecord[nLose],dfAll.underdogRecord[nLose],'rx')

# pct correct according to spread
print (len(nWin)/ (len(nWin) + len(nLose)))

# pct correct according to model
nWin = dfAll.predictWin.index.tolist()
nLose = dfAll[dfAll['predictWin'] == 0].index.tolist()
print (len(nWin)/ (len(nWin) + len(nLose)))

# %% [markdown]
# ### loop over multiple years
# see how different classifiers or test/train combos perform over the years

# %%
# loop over multiple years

import runMadden
reload(madden)
reload(runMadden)

def runLoop():
    path_to_lines = dataRoot + "lines/"

    trainStart = 2013
    trainLen = 1

    mlClassifier = svm.SVC(kernel='poly',probability=True)
    dfSVM = runMadden.runSeasonLoop(trainStart, trainLen, mlClassifier, path_to_lines, reference_data)

    #mlClassifier = linear_model.LogisticRegression(C=1e5)
    #dfLog = runMadden.runSeasonLoop(trainStart, trainLen, mlClassifier, path_to_lines, reference_data)
    dfLoop = dfSVM
    return(dfLoop)

def runSeason():
    path_to_lines = dataRoot + "lines/"
    dfAllGames = madden.readGamesAll(path_to_lines, seasons)
    dfAllTeams = madden.seasonRecord(dfAllGames, reference_data)

# %%
reload(madden)
reload(runMadden)

path_to_lines = dataRoot + "lines/"

trainStart = 2013
trainLen = 1

#mlClassifier = svm.SVC(kernel='poly',probability=True)
#dfSVM = runMadden.runSeasonLoop(trainStart, trainLen, mlClassifier, path_to_lines, reference_data)

mlClassifier = linear_model.LogisticRegression(C=1e5)
dfLog = runMadden.runSeasonLoop(trainStart, trainLen, mlClassifier, path_to_lines, reference_data)
# Out:
# 2014 [2013]
# training data accuracy =
#  0.70703125
# predict accuracy =  0.658385093168
#              score  win by   win
# lineScore     1044    1044  True
# probaScore1   1056    1056  True
# probaScore2   1036    1036  True
# probaScore3   1025    1025  True
# 1044.0 <type 'numpy.float64'>

# %%
reload(madden)

trainYears = [2013] 
testYear = [2014]

seasons = np.array(trainYears)
seasonTest = np.array(testYear)

# test new wrapper object
oSeason = madden.SeasonClassifier(path_to_lines, reference_data)
oSeason.readData(seasons, 'train')
oSeason.readData(seasonTest, 'test')
oSeason.setFeatures(features)
mlClassifier = linear_model.LogisticRegression(C=1e5)
oSeason.setClassifier(mlClassifier)
oSeason.runClassifier('favoredWin')
oSeason.predict()
oSeason.predictAccuracy('train')
oSeason.rank()
oSeason.predictSummary(week=12, guessCol='probaGuess')
# Out:
# training data accuracy =  0.70703125
# predict accuracy =  0.70703125
#              score  win by   win
# lineScore     1044    1044  True
# probaScore1   1056    1056  True
# probaScore2   1036    1036  True
# probaScore3   1025    1025  True
#                predictTeam  predict_proba  probaGuess              favorite  \
# 8596    Indianapolis Colts       0.910224          16    Indianapolis Colts
# 8599   Philadelphia Eagles       0.873100          15   Philadelphia Eagles
# 8591    Kansas City Chiefs       0.795660          14    Kansas City Chiefs
# 8593         Buffalo Bills       0.767750          13         Buffalo Bills
# 8603   San Francisco 49ers       0.766246          12   San Francisco 49ers
# 8597     Green Bay Packers       0.747365          11     Green Bay Packers
# 8602        Denver Broncos       0.735228          10        Denver Broncos
# 8598  New England Patriots       0.731976           9  New England Patriots
# 8600    San Diego Chargers       0.702623           8    San Diego Chargers
# 8601      Seattle Seahawks       0.671804           7      Seattle Seahawks
# 8594         Chicago Bears       0.668506           6         Chicago Bears
# 8604        Dallas Cowboys       0.658187           5        Dallas Cowboys
# 8595        Houston Texans       0.562275           4        Houston Texans
# 8605    New Orleans Saints       0.533561           3    New Orleans Saints
# 8592      Cleveland Browns       0.467031           2       Atlanta Falcons
#
#       Line
# 8596  14.0
# 8599  11.0
# 8591  -7.0
# 8593   4.5
# 8603   8.5
# 8597  -9.5
# 8602   7.0
# 8598   7.0
# 8600   5.0
# 8601   6.5
# 8594   5.5
# 8604  -3.0
# 8595   2.0
# 8605   3.5
# 8592   3.0

# %%
oSeason.predictSummary(week=12, guessCol='probaGuess')
# Out:
#                predictTeam  predict_proba  probaGuess              favorite  \
# 8596    Indianapolis Colts       0.910224          16    Indianapolis Colts
# 8599   Philadelphia Eagles       0.873100          15   Philadelphia Eagles
# 8591    Kansas City Chiefs       0.795660          14    Kansas City Chiefs
# 8593         Buffalo Bills       0.767750          13         Buffalo Bills
# 8603   San Francisco 49ers       0.766246          12   San Francisco 49ers
# 8597     Green Bay Packers       0.747365          11     Green Bay Packers
# 8602        Denver Broncos       0.735228          10        Denver Broncos
# 8598  New England Patriots       0.731976           9  New England Patriots
# 8600    San Diego Chargers       0.702623           8    San Diego Chargers
# 8601      Seattle Seahawks       0.671804           7      Seattle Seahawks
# 8594         Chicago Bears       0.668506           6         Chicago Bears
# 8604        Dallas Cowboys       0.658187           5        Dallas Cowboys
# 8595        Houston Texans       0.562275           4        Houston Texans
# 8605    New Orleans Saints       0.533561           3    New Orleans Saints
# 8592      Cleveland Browns       0.467031           2       Atlanta Falcons
#
#       Line
# 8596  14.0
# 8599  11.0
# 8591  -7.0
# 8593   4.5
# 8603   8.5
# 8597  -9.5
# 8602   7.0
# 8598   7.0
# 8600   5.0
# 8601   6.5
# 8594   5.5
# 8604  -3.0
# 8595   2.0
# 8605   3.5
# 8592   3.0

# %%
oSeason.predictSummary(week=12, guessCol='lineGuess')
# Out:
#                predictTeam  predict_proba  lineGuess              favorite  \
# 8596    Indianapolis Colts       0.910224         16    Indianapolis Colts
# 8599   Philadelphia Eagles       0.873100         15   Philadelphia Eagles
# 8597     Green Bay Packers       0.747365         14     Green Bay Packers
# 8603   San Francisco 49ers       0.766246         13   San Francisco 49ers
# 8598  New England Patriots       0.731976         12  New England Patriots
# 8602        Denver Broncos       0.735228         11        Denver Broncos
# 8591    Kansas City Chiefs       0.795660         10    Kansas City Chiefs
# 8601      Seattle Seahawks       0.671804          9      Seattle Seahawks
# 8594         Chicago Bears       0.668506          8         Chicago Bears
# 8600    San Diego Chargers       0.702623          7    San Diego Chargers
# 8593         Buffalo Bills       0.767750          6         Buffalo Bills
# 8605    New Orleans Saints       0.533561          5    New Orleans Saints
# 8592      Cleveland Browns       0.467031          4       Atlanta Falcons
# 8604        Dallas Cowboys       0.658187          3        Dallas Cowboys
# 8595        Houston Texans       0.562275          2        Houston Texans
#
#       Line
# 8596  14.0
# 8599  11.0
# 8597  -9.5
# 8603   8.5
# 8598   7.0
# 8602   7.0
# 8591  -7.0
# 8601   6.5
# 8594   5.5
# 8600   5.0
# 8593   4.5
# 8605   3.5
# 8592   3.0
# 8604  -3.0
# 8595   2.0

# %%
dfSVM
# Out:
#         2014.0  lineScore  probaScore1  probaScore2  probaScore3 trainYears  \
# season
# 2014       NaN        NaN          NaN          NaN          NaN     [2013]
#
#                                            classifierType
# season
# 2014    SVC(C=1.0, cache_size=200, class_weight=None, ...
